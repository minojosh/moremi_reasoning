# %% [markdown]
# # Salesforce BLIP3-OCR-200M Data Processing and Reasoning Trace Generation
#
# **Objective:** Utilize the `Salesforce/blip3-ocr-200m` dataset to extract OCR information and then generate reasoning traces using a specified language model. This notebook will be run in a Kaggle SSH environment.

# %% [markdown]
# ## 1. Setup and Installations
#
# Install necessary Python packages for data handling, Hugging Face interactions, and any other dependencies required by the `multimodal_QRA_pair.py` script and the chosen models.

# %%
# Ensure these packages are installed in your Kaggle environment
# You might need to restart the kernel after running this cell for the first time.
# !pip install datasets pandas huggingface_hub pyarrow tqdm dotenv
# !git clone https://github.com/minojosh/moremi_reasoning.git

# %%
import os
import sys
from pathlib import Path


def set_working_directory():

    # Get the current working directory
    current_dir = Path(os.getcwd())

    # Check if the script is running in a Kaggle environment
    if "KAGGLE_KERNEL_RUN_TYPE" in os.environ:
        # Set the working directory to the parent directory of the script / moremi_reasoning
        parent_dir = current_dir.parent
        os.chdir(parent_dir / "working/moremi_reasoning")
        working_dir = sys.path.append(str(parent_dir))
        # print(f"Working directory set to: {working_dir}")
    else:
        # If not in Kaggle, set the working directory to the script's directory
        os.chdir(current_dir)
        sys.path.append(str(current_dir))


set_working_directory()
os.getcwd()
# Out:
# '/kaggle/working/moremi_reasoning'

# %%
# # Option 1: Stash your local changes, pull, then reapply (recommended)
# !git stash push -m "Local config changes before pull"
# !git pull origin main
# !git stash pop

# %%
path = "src/config"
os.listdir(path)
# Out:
# ['settings.yaml',
#  'reasoning_config.yaml',
#  'reasoning_config.yaml.backup',
#  'reasoning_prompts.yaml',
#  'modalities.yaml']

# %%
# !git config --global user.email "joshua@minohealth.org"
# !git config --global user.name "minojosh"
# # !git add 'src/config/reasoning_config.yaml'
# # !git commit -m "Update reasoning_config.yaml"
# !git push origin main

# %%
# login to huggingface_hub with HF_TOKEN from secrets
from huggingface_hub import login
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
HF_TOKEN = user_secrets.get_secret("HF_TOKEN")
login(HF_TOKEN)
OPEN_ROUTER_API_KEY = user_secrets.get_secret("OPEN_ROUTER_API_KEY")
API_KEY = OPEN_ROUTER_API_KEY

# %% [markdown]
# ## 2. Import Libraries

# %%
import os
import json
import pandas as pd
from datasets import load_dataset
from huggingface_hub import HfApi, snapshot_download
import yaml
from tqdm.auto import tqdm

# Potentially more imports will be needed based on multimodal_QRA_pair.py
# and the specific models used.

# %%
os.listdir()
# Out:
# ['salesforce_data',
#  'salesforce_images',
#  'logs',
#  'salesforce_images.zip',
#  '.gitignore',
#  'section_5_enhancement_summary.md',
#  'all_image_files.txt',
#  'ocr_test_data.json',
#  'ocr_test_samples_from_list.json',
#  'salesforce_ocr',
#  'README.md',
#  'state.db',
#  'output.json',
#  '.git',
#  'src']

# %%
# !rm -rf section_5_enhancement_summary.md

# %%
path = "salesforce_ocr"
os.listdir()
# Out:
# ['salesforce_data',
#  'salesforce_images',
#  'logs',
#  'salesforce_images.zip',
#  '.gitignore',
#  'all_image_files.txt',
#  'ocr_test_data.json',
#  'ocr_test_samples_from_list.json',
#  'salesforce_ocr',
#  'README.md',
#  'state.db',
#  'output.json',
#  '.git']

# %% [markdown]
# ## 3. Configuration Loading
#
# Load project configurations. Critical paths like `data_path` and `image_dir` need to be correctly set for the Kaggle environment.

# %%
# Path to the configuration file (relative to this notebook)
CONFIG_PATH = "src/config/reasoning_config.yaml"
PROMPTS_PATH = "src/config/reasoning_prompts.yaml"


def load_config(path):
    with open(path, "r") as f:
        return yaml.safe_load(f)


print(f"Loading configuration from: {CONFIG_PATH}")
config = load_config(CONFIG_PATH)
print(f"Loading prompts from: {PROMPTS_PATH}")
prompts = load_config(PROMPTS_PATH)

# --- CRITICAL: REVIEW AND UPDATE THESE PATHS FOR KAGGLE ---
print("\n--- CONFIGURATION REQUIRES YOUR ATTENTION ---")
print(f"Current data_path: {config.get('data_path')}")
print(
    "ACTION: Update 'data_path' in reasoning_config.yaml to the Kaggle path for Salesforce Parquet files."
)

print(f"Current image_dir: {config.get('image_dir')}")
print(
    "ACTION: Update 'image_dir' in reasoning_config.yaml to the Kaggle path for images, if applicable."
)

print(f"Current model_name (for reasoning): {config.get('model_name')}")
print(f"API URL (for reasoning model): {config.get('api_url')}")

api_key = OPEN_ROUTER_API_KEY
if api_key:
    print(f"✓ API key already set (length: {len(api_key)})")
else:
    print("⚠️ API_KEY not set!")
    print("Please set your OpenRouter API key:")
    print("  os.environ['API_KEY'] = 'your_actual_api_key_here'")
    print("Or run in terminal: export API_KEY='your_actual_api_key_here'")
print("---------------------------------------------")
# Out:
# Loading configuration from: src/config/reasoning_config.yaml
# Loading prompts from: src/config/reasoning_prompts.yaml
#
# --- CONFIGURATION REQUIRES YOUR ATTENTION ---
# Current data_path: /kaggle/working/moremi_reasoning/ocr_test_samples_from_list.json
# ACTION: Update 'data_path' in reasoning_config.yaml to the Kaggle path for Salesforce Parquet files.
# Current image_dir: /kaggle/working/moremi_reasoning/salesforce_images
# ACTION: Update 'image_dir' in reasoning_config.yaml to the Kaggle path for images, if applicable.
# Current model_name (for reasoning): google/gemini-2.0-flash-001
# API URL (for reasoning model): https://openrouter.ai/api/v1
# ✓ API key already set (length: 73)
# ---------------------------------------------

# %% [markdown]
# ## 4. Load Salesforce BLIP3-OCR-200M Dataset
#
# Load the dataset. This might involve using `load_dataset` from Hugging Face `datasets` or directly reading Parquet files if downloaded via `huggingface_hub` or available through Kaggle datasets.

# %%
import logging
import sys
import os
from tqdm import tqdm

from huggingface_hub import HfApi, snapshot_download

# Use our previously defined random numbers to select files
prefixes = ["001","047"]  # Original prefixes
# prefixes = [
#     f"{str(n).zfill(3)}" for n in random_numbers
# ]  # Use the random numbers instead
download_list = [f"{prefix}.parquet" for prefix in prefixes]

# Create a directory for data if it doesn't exist
SALESFORCE_DATA_PATH = os.path.join(os.getcwd(), "salesforce_data")
os.makedirs(SALESFORCE_DATA_PATH, exist_ok=True)

# Update the data_path in config for later use
config["data_path"] = SALESFORCE_DATA_PATH
print(f"Updated data_path in config to: {SALESFORCE_DATA_PATH}")


def download_files(download_list, output_dir):
    """
    Function to download files from the Hugging Face Hub.
    Args:
        download_list (list): List of files to download.
        output_dir (str): Directory to save the downloaded files.
    """
    api = HfApi()
    for file in tqdm(download_list, desc="Downloading parquet files"):
        try:
            api.hf_hub_download(
                repo_id="Salesforce/blip3-ocr-200m",
                repo_type="dataset",
                filename=file,
                local_dir=output_dir,
                local_dir_use_symlinks=False,
            )
            print(f"Successfully downloaded {file} to {output_dir}")
        except Exception as e:
            print(f"Error downloading {file}: {e}")


# Download the files
print(f"Downloading {len(download_list)} parquet files: {download_list}")
download_files(download_list, SALESFORCE_DATA_PATH)

# %% [markdown]
# ### 4.1. Specify Parquet File and Load Data
#
# Ensure `SALESFORCE_DATA_PATH` in Cell 7 (Configuration Loading) is correctly set to the directory containing your Parquet files in the Kaggle environment. We'll load one file to start.

# %%
import os

os.getcwd()
MOREMI_REASONING_PATH = os.path.join(os.getcwd(), "moremi_reasoning")
os.chdir(MOREMI_REASONING_PATH)
print(f"Current working directory: {os.getcwd()}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_71/2992068576.py in <cell line: 0>()
#       3 os.getcwd()
#       4 MOREMI_REASONING_PATH = os.path.join(os.getcwd(), "moremi_reasoning")
# ----> 5 os.chdir(MOREMI_REASONING_PATH)
#       6 print(f"Current working directory: {os.getcwd()}")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/working/moremi_reasoning/moremi_reasoning'

# %%
# Assuming SALESFORCE_DATA_PATH is a directory containing the .parquet files
# This was defined in Cell 7 based on your config.
import os
import pandas as pd
import sys

os.getcwd()

# Let's list available parquet files if the path is a directory
SALESFORCE_DATA_PATH = os.path.join(os.getcwd(), "salesforce_data")
parquet_file_to_load = None
if (
    SALESFORCE_DATA_PATH
    and os.path.exists(SALESFORCE_DATA_PATH)
    and os.path.isdir(SALESFORCE_DATA_PATH)
):
    all_parquet_files = sorted(
        [
            os.path.join(SALESFORCE_DATA_PATH, f)
            for f in os.listdir(SALESFORCE_DATA_PATH)
            if f.endswith(".parquet")
        ]
    )
    if all_parquet_files:
        parquet_file_to_load = all_parquet_files[1]  # Load the first file
        print(
            f"Found {len(all_parquet_files)} Parquet files. Will load: {parquet_file_to_load}"
        )
    else:
        print(f"ERROR: No .parquet files found in directory: {SALESFORCE_DATA_PATH}")
else:
    print(
        f"ERROR: SALESFORCE_DATA_PATH ('{SALESFORCE_DATA_PATH}') is not a valid directory or does not exist. Please check Cell 7."
    )

# Load the selected Parquet file into a Pandas DataFrame
df = None
if parquet_file_to_load:
    try:
        # Shrink parquet before loading
        # %pip install pyarrow -q
        import pyarrow.parquet as pq
        
        # Read the parquet file metadata to see available columns
        parquet_metadata = pq.read_metadata(parquet_file_to_load)
        print(f"Total rows in file: {parquet_metadata.num_rows}")
        
        # Get column names from metadata
        column_names = []
        for i in range(parquet_metadata.num_columns):
            column_names.append(parquet_metadata.schema.names[i])
        print(f"Available columns: {column_names}")
        
        # Read only the first 10 rows and selected columns
        table = pq.read_table(
            parquet_file_to_load, 
            columns=column_names,
            use_threads=True
        )

    except Exception as e:
        print(f"Error loading Parquet file {parquet_file_to_load}: {e}")
# Out:
# Found 2 Parquet files. Will load: /kaggle/working/moremi_reasoning/salesforce_data/037.parquet
# Note: you may need to restart the kernel to use updated packages.
# Total rows in file: 3904179
# Available columns: ['uid', 'face_bboxes', 'url', 'key', 'captions', 'metadata', '__index_level_0__']

# %%
# Select 5000 random rows with fixed seed
import numpy as np
import random
import pyarrow as pa
import pyarrow.parquet as pq
import pandas as pd

SEED = 42
N = 15000

# Set seed for reproducibility
np.random.seed(SEED)
random.seed(SEED)

# Get total row count
total_rows = table.num_rows
print(f"Total rows in dataset: {total_rows}")

# Generate random indices
if total_rows > N:
    random_indices = sorted(np.random.choice(total_rows, size=N, replace=False))

    # Use pyarrow directly to read specific rows efficiently
    reader = pq.ParquetFile(parquet_file_to_load)

    # Read in batches and collect only the rows we need
    all_selected_rows = []
    current_row = 0

    for batch in reader.iter_batches(batch_size=10000):
        batch_df = batch.to_pandas()
        batch_size = len(batch_df)

        # Find which random indices fall within this batch
        batch_indices = [
            i - current_row
            for i in random_indices
            if current_row <= i < current_row + batch_size
        ]

        if batch_indices:
            selected_rows = batch_df.iloc[batch_indices]
            all_selected_rows.append(selected_rows)

        current_row += batch_size

        # Early stopping if we've processed all needed indices
        if current_row > max(random_indices):
            break

    # Combine all selected rows
    df = pd.concat(all_selected_rows, ignore_index=True)
else:
    # If we have fewer than N rows, just use the whole table
    df = table.to_pandas()
    print(f"Warning: Requested {N} rows but dataset only has {total_rows} rows.")

# Save to file in chunks to avoid memory issues
output_path = "output.json"
chunk_size = 500
for i in range(0, len(df), chunk_size):
    chunk = df.iloc[i : i + chunk_size]
    mode = "w" if i == 0 else "a"
    chunk.to_json(output_path, orient="records", lines=True, mode=mode)

print(f"Selected {len(df)} random rows from {total_rows} total rows")
print(f"Data saved to {output_path}")
print(df.head())  # Print only the first few rows
# df
# Out:
# Total rows in dataset: 3904179
# Selected 15000 random rows from 3904179 total rows
# Data saved to output.json
#                                 uid  \
# 0  6372b42d9b959cf13d343a9b89744ef4
# 1  6311b021e5d9f170c075eaf6b7e0aab1
# 2  ab76c147109d324901f1a89306e1eb08
# 3  d3b5fcc722628afbb52c8e987cab532f
# 4  3850c90d2af63aea53310542ddbe44d2
#
#                                          face_bboxes  \
# 0  [[0.6712742447853088, 0.5487404465675354, 0.69...
# 1  [[0.6411637663841248, 0.6060816049575806, 0.74...
# 2  [[0.06078694760799408, 0.17436712980270386, 0....
# 3                                                 []
# 4                                                 []
#
#                                                  url           key  \
# 0  http://direct-ns.rhap.com/imageserver/v2/album...  000008121023
# 1  https://encrypted-tbn0.gstatic.com/images?q=tb...  000008123345
# 2  https://www.azquotes.com/picture-quotes/quote-...  000008126392
# 3  https://facty.mblycdn.com/uploads/fh/2021/01/1...  000008127675
# 4  https://cdn.practicaldatacore.com/sportsunlimi...  000008127998
#
#                                             captions  \
# 0  [{"text": "The image contains the text \"THE B...
# 1  [{"text": "The image contains the text \"Befor...
# 2  [{"text": "The image contains the text \"To wa...
# 3  [{"text": "The image contains the text \"prote...
# 4  [{"text": "The image contains the text \"ANADI...
#
#                                             metadata
# 0  {"length": 3, "entries": [{"bbox": [[0.3058823...
# 1  {"length": 4, "entries": [{"bbox": [[0.7309417...
# 2  {"length": 8, "entries": [{"bbox": [[0.4117647...
# 3  {"length": 5, "entries": [{"bbox": [[0.0297619...
# 4  {"length": 1, "entries": [{"bbox": [[0.2142857...

# %% [markdown]
# ### 4.2. Explore a Sample Row
#
# Let's examine the content of a single row, focusing on `uid`, `url`, `captions`, and `metadata`.

# %%
def explore_sample_row(dataframe, index=0):
    if dataframe is None or dataframe.empty:
        print("DataFrame is not loaded or is empty.")
        return
    if index >= len(dataframe):
        print(
            f"Index {index} is out of bounds for DataFrame of length {len(dataframe)}."
        )
        return

    sample = dataframe.iloc[index]
    print(f"--- Exploring Sample Row (Index: {index}) ---")
    print(f"UID: {sample.get('uid')}")
    print(f"Key: {sample.get('key')}")
    image_url = sample.get("url")
    print(f"Image URL: {image_url}")

    print("\n--- Parsed Captions (from 'captions' field) ---")
    captions_str = sample.get("captions")
    if captions_str:
        try:
            captions_list = json.loads(captions_str)
            for i, cap_obj in enumerate(captions_list):
                print(f"  Caption Entry {i}:")
                print(f"    Granularity: {cap_obj.get('granularity')}")
                print(
                    f"    Include DataComp Raw Cap: {cap_obj.get('include_datacomp_raw_cap')}"
                )
                # Limit printing of very long text fields
                ocr_text = cap_obj.get("text", "")
                print(
                    f"    Text: {ocr_text[:500] + ('...' if len(ocr_text) > 500 else '')}"
                )
        except json.JSONDecodeError as e:
            print(f"  Error parsing 'captions' JSON: {e}")
            print(f"  Raw captions string: {captions_str}")
    else:
        print("  'captions' field is missing or empty.")

    print("\n--- Parsed Metadata (from 'metadata' field) ---")
    metadata_str = sample.get("metadata")
    if metadata_str:
        try:
            metadata_obj = json.loads(metadata_str)
            print(f"  Length (tokens): {metadata_obj.get('length')}")
            print(f"  OCR UID: {metadata_obj.get('uid')}")
            entries = metadata_obj.get("entries", [])
            print(f"  Number of token entries: {len(entries)}")
            if entries:
                print("    First 3 token entries (if available):")
                for i, entry in enumerate(entries[:3]):
                    print(
                        f"      Token {i}: Text='{entry.get('text')}', Confidence={entry.get('confidence')}, BBox={entry.get('bbox')}"
                    )
        except json.JSONDecodeError as e:
            print(f"  Error parsing 'metadata' JSON: {e}")
            print(f"  Raw metadata string: {metadata_str}")
    else:
        print("  'metadata' field is missing or empty.")


if df is not None:
    explore_sample_row(df, 0)  # Explore the first row
    if len(df) > 1:
        explore_sample_row(df, 1)  # Explore the second row if available
# Out:
# --- Exploring Sample Row (Index: 0) ---
# UID: 73142d356bceb4a9b16e41f7a78807e9
# Key: 000008120942
# Image URL: https://d2840bd96689bd871bd1-41a6b1bb2f8a7c769906f5cde19335fe.ssl.cf1.rackcdn.com/thumbnails/3HGGK5H46LM702372/0d58289257f95d4db9562b8e86124ab5.jpg
#
# --- Parsed Captions (from 'captions' field) ---
#   Caption Entry 0:
#     Granularity: 0
#     Include DataComp Raw Cap: False
#     Text: The image contains the text "BOCH", the text "20 Year / 200,000 Mile Warranty"
#   Caption Entry 1:
#     Granularity: 1
#     Include DataComp Raw Cap: False
#     Text: The image contains the text "BOCH" located at the bottom left corner, the text "20 Year / 200,000 Mile Warranty" located below the center
#   Caption Entry 2:
#     Granularity: 2
#     Include DataComp Raw Cap: False
#     Text: The image contains the text "BOCH" located at 18/19 of the image from top to bottom and 2/15 of the image from left to right, the text "20 Year / 200,000 Mile Warranty" located at 18/19 of the image from top to bottom and 10/19 of the image from left to right
#   Caption Entry 3:
#     Granularity: 3
#     Include DataComp Raw Cap: False
#     Text: The image contains the text "BOCH" approximately starts at [0.1, 0.9] and extends upto [0.2, 1.0], the text "20 Year / 200,000 Mile Warranty" approximately starts at [0.3, 0.9] and extends upto [0.7, 1.0]
#   Caption Entry 4:
#     Granularity: 4
#     Include DataComp Raw Cap: False
#     Text: The image contains the text "BOCH" starts at [0.074, 0.906] and extends upto [0.201, 0.987], the text "20 Year / 200,000 Mile Warranty" starts at [0.304, 0.92] and extends upto [0.746, 0.973]
#   Caption Entry 5:
#     Granularity: 5
#     Include DataComp Raw Cap: False
#     Text: The image contains the <ocr>"BOCH</ocr><bbox>[0.074, 0.906][0.201, 0.987]</bbox>, the <ocr>"20 Year / 200,000 Mile Warranty</ocr><bbox>[0.304, 0.92][0.746, 0.973]</bbox>
#   Caption Entry 6:
#     Granularity: 0
#     Include DataComp Raw Cap: True
#     Text: 2020 Honda Fit LX CVT. The image contains the text "BOCH", the text "20 Year / 200,000 Mile Warranty"
#   Caption Entry 7:
#     Granularity: 1
#     Include DataComp Raw Cap: True
#     Text: 2020 Honda Fit LX CVT. The image contains the text "BOCH" located at the bottom left corner, the text "20 Year / 200,000 Mile Warranty" located below the center
#   Caption Entry 8:
#     Granularity: 2
#     Include DataComp Raw Cap: True
#     Text: 2020 Honda Fit LX CVT. The image contains the text "BOCH" located at 18/19 of the image from top to bottom and 2/15 of the image from left to right, the text "20 Year / 200,000 Mile Warranty" located at 18/19 of the image from top to bottom and 10/19 of the image from left to right
#   Caption Entry 9:
#     Granularity: 3
#     Include DataComp Raw Cap: True
#     Text: 2020 Honda Fit LX CVT. The image contains the text "BOCH" approximately starts at [0.1, 0.9] and extends upto [0.2, 1.0], the text "20 Year / 200,000 Mile Warranty" approximately starts at [0.3, 0.9] and extends upto [0.7, 1.0]
#   Caption Entry 10:
#     Granularity: 4
#     Include DataComp Raw Cap: True
#     Text: 2020 Honda Fit LX CVT. The image contains the text "BOCH" starts at [0.074, 0.906] and extends upto [0.201, 0.987], the text "20 Year / 200,000 Mile Warranty" starts at [0.304, 0.92] and extends upto [0.746, 0.973]
#   Caption Entry 11:
#     Granularity: 5
#     Include DataComp Raw Cap: True
#     Text: 2020 Honda Fit LX CVT. The image contains the <ocr>"BOCH</ocr><bbox>[0.074, 0.906][0.201, 0.987]</bbox>, the <ocr>"20 Year / 200,000 Mile Warranty</ocr><bbox>[0.304, 0.92][0.746, 0.973]</bbox>
#
# --- Parsed Metadata (from 'metadata' field) ---
#   Length (tokens): 2
#   OCR UID: datacomp_ocr_73142d356bceb4a9b16e41f7a78807e9
#   Number of token entries: 2
#     First 3 token entries (if available):
#       Token 0: Text='BOCH', Confidence=0.9978278875350952, BBox=[[0.07357859531772576, 0.90625], [0.20066889632107024, 0.90625], [0.20066889632107024, 0.9866071428571429], [0.07357859531772576, 0.9866071428571429]]
#       Token 1: Text='20 Year / 200,000 Mile Warranty', Confidence=0.9483230113983154, BBox=[[0.30434782608695654, 0.9196428571428571], [0.745819397993311, 0.9241071428571429], [0.745819397993311, 0.9732142857142857], [0.30434782608695654, 0.96875]]
# --- Exploring Sample Row (Index: 1) ---
# UID: ea556b0fbaa509f7eadcb690ad672198
# Key: 000008129583
# Image URL: https://cv1.litres.ru/pub/c/cover/24166812.jpg
#
# --- Parsed Captions (from 'captions' field) ---
#   Caption Entry 0:
#     Granularity: 0
#     Include DataComp Raw Cap: False
#     Text: The image contains the text "GEORGE", the text "ANSON", the text "A VOYAGE", the text "ROUND THE", the text "WORLD"
#   Caption Entry 1:
#     Granularity: 1
#     Include DataComp Raw Cap: False
#     Text: The image contains the text "GEORGE" located at the top left corner, the text "ANSON" located at the top left corner, the text "A VOYAGE" located in the center, the text "ROUND THE" located in the center, the text "WORLD" located at the bottom left corner
#   Caption Entry 2:
#     Granularity: 2
#     Include DataComp Raw Cap: False
#     Text: The image contains the text "GEORGE" located at 3/20 of the image from top to bottom and 1/3 of the image from left to right, the text "ANSON" located at 5/18 of the image from top to bottom and 4/13 of the image from left to right, the text "A VOYAGE" located at 5/11 of the image from top to bottom and 7/18 of the image from left to right, the text "ROUND THE" located at 7/12 of the image from top to bottom and 2/5 of the image from left to right, the text "WORLD" located at 5/7 of the image fr...
#   Caption Entry 3:
#     Granularity: 3
#     Include DataComp Raw Cap: False
#     Text: The image contains the text "GEORGE" approximately starts at [0.1, 0.1] and extends upto [0.5, 0.2], the text "ANSON" approximately starts at [0.1, 0.2] and extends upto [0.5, 0.3], the text "A VOYAGE" approximately starts at [0.1, 0.4] and extends upto [0.7, 0.5], the text "ROUND THE" approximately starts at [0.1, 0.5] and extends upto [0.7, 0.6], the text "WORLD" approximately starts at [0.1, 0.7] and extends upto [0.5, 0.8]
#   Caption Entry 4:
#     Granularity: 4
#     Include DataComp Raw Cap: False
#     Text: The image contains the text "GEORGE" starts at [0.125, 0.096] and extends upto [0.536, 0.197], the text "ANSON" starts at [0.121, 0.226] and extends upto [0.491, 0.328], the text "A VOYAGE" starts at [0.125, 0.408] and extends upto [0.652, 0.503], the text "ROUND THE" starts at [0.121, 0.535] and extends upto [0.67, 0.631], the text "WORLD" starts at [0.125, 0.659] and extends upto [0.5, 0.761]
#   Caption Entry 5:
#     Granularity: 5
#     Include DataComp Raw Cap: False
#     Text: The image contains the <ocr>"GEORGE</ocr><bbox>[0.125, 0.096][0.536, 0.197]</bbox>, the <ocr>"ANSON</ocr><bbox>[0.121, 0.226][0.491, 0.328]</bbox>, the <ocr>"A VOYAGE</ocr><bbox>[0.125, 0.408][0.652, 0.503]</bbox>, the <ocr>"ROUND THE</ocr><bbox>[0.121, 0.535][0.67, 0.631]</bbox>, the <ocr>"WORLD</ocr><bbox>[0.125, 0.659][0.5, 0.761]</bbox>
#   Caption Entry 6:
#     Granularity: 0
#     Include DataComp Raw Cap: True
#     Text: Anson George A Voyage Round the World willis george emerson the smoky god or a voyage to the inner world. The image contains the text "GEORGE", the text "ANSON", the text "A VOYAGE", the text "ROUND THE", the text "WORLD"
#   Caption Entry 7:
#     Granularity: 1
#     Include DataComp Raw Cap: True
#     Text: Anson George A Voyage Round the World willis george emerson the smoky god or a voyage to the inner world. The image contains the text "GEORGE" located at the top left corner, the text "ANSON" located at the top left corner, the text "A VOYAGE" located in the center, the text "ROUND THE" located in the center, the text "WORLD" located at the bottom left corner
#   Caption Entry 8:
#     Granularity: 2
#     Include DataComp Raw Cap: True
#     Text: Anson George A Voyage Round the World willis george emerson the smoky god or a voyage to the inner world. The image contains the text "GEORGE" located at 3/20 of the image from top to bottom and 1/3 of the image from left to right, the text "ANSON" located at 5/18 of the image from top to bottom and 4/13 of the image from left to right, the text "A VOYAGE" located at 5/11 of the image from top to bottom and 7/18 of the image from left to right, the text "ROUND THE" located at 7/12 of the image f...
#   Caption Entry 9:
#     Granularity: 3
#     Include DataComp Raw Cap: True
#     Text: Anson George A Voyage Round the World willis george emerson the smoky god or a voyage to the inner world. The image contains the text "GEORGE" approximately starts at [0.1, 0.1] and extends upto [0.5, 0.2], the text "ANSON" approximately starts at [0.1, 0.2] and extends upto [0.5, 0.3], the text "A VOYAGE" approximately starts at [0.1, 0.4] and extends upto [0.7, 0.5], the text "ROUND THE" approximately starts at [0.1, 0.5] and extends upto [0.7, 0.6], the text "WORLD" approximately starts at [0...
#   Caption Entry 10:
#     Granularity: 4
#     Include DataComp Raw Cap: True
#     Text: Anson George A Voyage Round the World willis george emerson the smoky god or a voyage to the inner world. The image contains the text "GEORGE" starts at [0.125, 0.096] and extends upto [0.536, 0.197], the text "ANSON" starts at [0.121, 0.226] and extends upto [0.491, 0.328], the text "A VOYAGE" starts at [0.125, 0.408] and extends upto [0.652, 0.503], the text "ROUND THE" starts at [0.121, 0.535] and extends upto [0.67, 0.631], the text "WORLD" starts at [0.125, 0.659] and extends upto [0.5, 0.7...
#   Caption Entry 11:
#     Granularity: 5
#     Include DataComp Raw Cap: True
#     Text: Anson George A Voyage Round the World willis george emerson the smoky god or a voyage to the inner world. The image contains the <ocr>"GEORGE</ocr><bbox>[0.125, 0.096][0.536, 0.197]</bbox>, the <ocr>"ANSON</ocr><bbox>[0.121, 0.226][0.491, 0.328]</bbox>, the <ocr>"A VOYAGE</ocr><bbox>[0.125, 0.408][0.652, 0.503]</bbox>, the <ocr>"ROUND THE</ocr><bbox>[0.121, 0.535][0.67, 0.631]</bbox>, the <ocr>"WORLD</ocr><bbox>[0.125, 0.659][0.5, 0.761]</bbox>
#
# --- Parsed Metadata (from 'metadata' field) ---
#   Length (tokens): 5
#   OCR UID: datacomp_ocr_ea556b0fbaa509f7eadcb690ad672198
#   Number of token entries: 5
#     First 3 token entries (if available):
#       Token 0: Text='GEORGE', Confidence=0.9891433119773865, BBox=[[0.125, 0.09554140127388536], [0.5357142857142857, 0.09554140127388536], [0.5357142857142857, 0.19745222929936307], [0.125, 0.19745222929936307]]
#       Token 1: Text='ANSON', Confidence=0.9976603388786316, BBox=[[0.12053571428571429, 0.22611464968152867], [0.49107142857142855, 0.22611464968152867], [0.49107142857142855, 0.32802547770700635], [0.12053571428571429, 0.32802547770700635]]
#       Token 2: Text='A VOYAGE', Confidence=0.9622215032577515, BBox=[[0.125, 0.40764331210191085], [0.6517857142857143, 0.40764331210191085], [0.6517857142857143, 0.5031847133757962], [0.125, 0.5031847133757962]]

# %% [markdown]
# ### 4.3. Retrieve Images from `url` key
#
# Based on the exploration, we'll retrieve or download the images via the url and track the files downloaded by thier `uid` so we can tell which image has a valid image and is accecible on the web.

# %%
import requests
from PIL import Image
from io import BytesIO
import os
from tqdm.auto import tqdm
import time
from tenacity import retry, stop_after_attempt, wait_fixed, wait_exponential

# Create a directory to store the images
IMAGE_DIR = os.path.join(os.getcwd(), "salesforce_images")
os.makedirs(IMAGE_DIR, exist_ok=True)
MAX_IMAGES_TO_DOWNLOAD = 15000  # Limit to prevent excessive downloads
DATA_SOURCE = "output.json"

# Update the image_dir in config for later use
config["image_dir"] = IMAGE_DIR
print(f"Images will be saved to: {IMAGE_DIR}")


# Function to download an image from URL
def download_image(url, uid, timeout=10, max_retries=3):
    """
    Downloads an image from a URL and saves it with the uid as filename.

    Args:
        url (str): URL of the image
        uid (str): Unique ID to use as filename
        timeout (int): Timeout in seconds for the request
        max_retries (int): Number of retry attempts

    Returns:
        tuple: (success (bool), path_if_successful (str) or error_message (str))
    """
    if not url:
        return False, "No URL provided"

    image_path = os.path.join(IMAGE_DIR, f"{uid}.jpg")

    # Check if already downloaded
    if os.path.exists(image_path):
        return True, image_path

    retry_count = 0
    while retry_count < max_retries:
        try:
            response = requests.get(url, timeout=timeout)
            if response.status_code == 200:
                try:
                    # Verify it's a valid image by opening it with PIL
                    img = Image.open(BytesIO(response.content))
                    img.save(image_path)
                    return True, image_path
                except Exception as e:
                    return False, f"Invalid image data: {str(e)}"
            else:
                retry_count += 1
                if retry_count == max_retries:
                    return False, f"HTTP error: {response.status_code}"
                time.sleep(1)  # Wait before retrying
        except requests.exceptions.Timeout:
            retry_count += 1
            if retry_count == max_retries:
                return False, "Request timed out"
            time.sleep(1)  # Wait before retrying
        except requests.exceptions.RequestException as e:
            return False, f"Request error: {str(e)}"

    return False, "Max retries exceeded"


# Download a sample of images (limit to prevent excessive downloads)
max_images_to_download = MAX_IMAGES_TO_DOWNLOAD

download_results = {}

if df is not None and not df.empty:
    num_to_download = min(len(df), max_images_to_download)
    print(f"Downloading {num_to_download} images...")

    for idx, row in tqdm(
        df.head(num_to_download).iterrows(),
        total=num_to_download,
        desc="Downloading images",
    ):
        uid = row.get("uid")
        url = row.get("url")

        if uid and url:
            success, result = download_image(url, uid)
            download_results[uid] = {"url": url, "success": success, "result": result}

    # Print download statistics
    successful_downloads = sum(1 for res in download_results.values() if res["success"])
    print(
        f"Successfully downloaded {successful_downloads} out of {len(download_results)} images."
    )

    # Print details of a few successful downloads
    successful_items = [item for item in download_results.items() if item[1]["success"]]
    if successful_items:
        print("\nSample of successful downloads:")
        for uid, data in successful_items[:3]:  # Show first 3 successful downloads
            print(f"  UID: {uid}")
            print(f"  Image path: {data['result']}")
            print(f"  URL: {data['url']}")
            print()

    # Print details of failed downloads
    failed_items = [item for item in download_results.items() if not item[1]["success"]]
    if failed_items:
        print("Sample of failed downloads:")
        for uid, data in failed_items[:3]:  # Show first 3 failed downloads
            print(f"  UID: {uid}")
            print(f"  Error: {data['result']}")
            print(f"  URL: {data['url']}")
            print()
# Out:
# Images will be saved to: /kaggle/working/moremi_reasoning/salesforce_images
# Downloading 15000 images...
# Downloading images:   0%|          | 0/15000 [00:00<?, ?it/s]

# %%
# save zip file of images
# !zip -r salesforce_images.zip salesforce_images
# Out:
#   adding: salesforce_images/ (stored 0%)
#   adding: salesforce_images/a39b38e28cdbf2aec2881327abf8d3f7.jpg (deflated 17%)
#   adding: salesforce_images/c5d49916ea5afbd3e38824b2436a725d.jpg (deflated 1%)
#   adding: salesforce_images/71689cde1602595155619fc6a61fb746.jpg (deflated 14%)
#   adding: salesforce_images/c5fef3a3dc7ceb49996b84b6c4ad5663.jpg (deflated 1%)
#   adding: salesforce_images/6376ce71d99cc392fc97e817701a8e31.jpg (deflated 0%)
#   adding: salesforce_images/3faae2fe35c1c73455f7ff17359acefe.jpg (deflated 6%)
#   adding: salesforce_images/4144cfc95294430ee8f09c6ad0245e32.jpg (deflated 1%)
#   adding: salesforce_images/3f678482a9a9232c0fb6af105c05ffb9.jpg (deflated 1%)
#   adding: salesforce_images/bf9a3d18b17551c8d0647b84999ce4d5.jpg (deflated 1%)
#   adding: salesforce_images/8cb41d758aa700775ca7b6c3b22b6060.jpg (deflated 3%)
#   adding: salesforce_images/85dea36edc1caa8063843119ef41fffb.jpg (deflated 2%)
#   adding: salesforce_images/7330da27782fe3f46e461d0420f23066.jpg (deflated 1%)
#   adding: salesforce_images/36c2ca0a2151ee6bda4531750ad7d130.jpg (deflated 21%)
#   adding: salesforce_images/ff1ab87832d350d2519eb616681f895d.jpg (deflated 10%)
#   adding: salesforce_images/6c05bf2e0b7482a9b0883c0e7e2c77c3.jpg (deflated 8%)
#   adding: salesforce_images/d86942b7f9a28844db5bc2dd67cdc320.jpg (deflated 34%)
#   adding: salesforce_images/902453786413c3f8bd97e0c5e31a4d0c.jpg (deflated 7%)
#   adding: salesforce_images/6487a1a617c643a0ff2c50d9b040ddc6.jpg (deflated 0%)
#   adding: salesforce_images/77a9f53236235e8750b2d787f519eec3.jpg (deflated 10%)
#   adding: salesforce_images/7cd634b97b282b1a0e81b397bd72d4cd.jpg (deflated 2%)
#   adding: salesforce_images/76444cc8db9baa3a9b9c0e3644f1d106.jpg (deflated 12%)
#   adding: salesforce_images/0d87cab175d58e97f2c5742d1d57e333.jpg (deflated 2%)
#   adding: salesforce_images/a37d4ee2480f6ddd33bb6662e23c8a32.jpg (deflated 0%)
#   adding: salesforce_images/97cfed505b1e0e393fcc3ea3fd9a0e92.jpg (deflated 1%)
#   adding: salesforce_images/a0ba1979fa87b45a77cce8d56d83902a.jpg (deflated 2%)
#   adding: salesforce_images/bb24dc9b15c15a20080a7fd854a5ec83.jpg (deflated 51%)
#   adding: salesforce_images/004e44cf851feb055379eed54441f23f.jpg (deflated 2%)
#   adding: salesforce_images/8b74a24d974c9bc56047d637cf053cef.jpg (deflated 5%)
#   adding: salesforce_images/7536b964b7f35b169e186d382a8d1b4c.jpg (deflated 3%)
#   adding: salesforce_images/ab89747eac7e913025602af17e77279a.jpg (deflated 4%)
#   adding: salesforce_images/192db119daa2035c19d423977c547998.jpg (deflated 1%)
#   adding: salesforce_images/966245a5ba13cc3bd49729a53de16076.jpg (deflated 1%)
#   adding: salesforce_images/b8dd324c2c28bd81e2df9c3ec20c1ffe.jpg (deflated 6%)
#   adding: salesforce_images/2cfea142a88650c421a6401763ea156c.jpg (deflated 1%)
#   adding: salesforce_images/78041df944b25ba90b7e1675aab7b8ab.jpg (deflated 4%)
#   adding: salesforce_images/549038295ae75e28e131472406373132.jpg (deflated 4%)
#   adding: salesforce_images/8ca5c8cc760a5dc6aaeed9e506cce5af.jpg (deflated 28%)
#   adding: salesforce_images/78d8c521b0c65adb53b7fa0f4e2b388a.jpg (deflated 3%)
#   adding: salesforce_images/ddf9c463c13cb1123439e858216882d8.jpg (deflated 10%)
#   adding: salesforce_images/624b0eddeac92da9267df048d6cc2daa.jpg (deflated 1%)
#   adding: salesforce_images/cb26ee065d4d497c2595499e0600bad2.jpg (deflated 2%)
#   adding: salesforce_images/a7368eaa06a8e899527f620d01c3156b.jpg (deflated 1%)
#   adding: salesforce_images/4201c65325eebdad86a249072e354119.jpg (deflated 8%)
#   adding: salesforce_images/1f9775bf1eec7f1f3d8b4a4d97fac011.jpg (deflated 3%)
#   adding: salesforce_images/4564f403b98bd5999755141ff032a1b1.jpg (deflated 6%)
#   adding: salesforce_images/2f49e8f089961818cdbadfa271f2ad8a.jpg (deflated 3%)
#   adding: salesforce_images/a3d084592afe9c08fddaa3b8e00ebbce.jpg (deflated 1%)
#   adding: salesforce_images/930a1622288e3d7b157390d0332d51ae.jpg (deflated 2%)
#   adding: salesforce_images/883dfdeb05d0e301869c626f03dea641.jpg (deflated 1%)
#   adding: salesforce_images/6352c3d95518c1faa3b3e3dc2bfd075d.jpg (deflated 6%)
#   adding: salesforce_images/2894220f40a39b2eacd33d4199773bc2.jpg (deflated 26%)
#   adding: salesforce_images/6d7c0bb451147c0ffaabe7aef1b07da7.jpg (deflated 1%)
#   adding: salesforce_images/bfbcc40a2612b66e69847ff406d43c67.jpg (deflated 15%)
#   adding: salesforce_images/d0c02d098734e6f47dcafffcc41e9e1e.jpg (deflated 2%)
#   adding: salesforce_images/ff70fc23159ca223b1692e9343d9bc68.jpg (deflated 1%)
#   adding: salesforce_images/381299bf2f52a0f48d941041d891c1d0.jpg (deflated 8%)
#   adding: salesforce_images/cd63a950bb870339142ef657c0bb71f7.jpg (deflated 13%)
#   adding: salesforce_images/244f52a67d0163df363ab28e13023d3f.jpg (deflated 3%)
#   adding: salesforce_images/b87bfcf0459b475b06cd24ba934f8ea8.jpg (deflated 3%)
#   adding: salesforce_images/0ddf640aa5689a8473e835711af6fdde.jpg (deflated 1%)
#   adding: salesforce_images/dfe80a49406771923bf455571215afa0.jpg (deflated 14%)
#   adding: salesforce_images/b946c79d865ff4b4e7d1753664915a2a.jpg (deflated 2%)
#   adding: salesforce_images/c7f45619ee806a808aa675e532d55e63.jpg (deflated 1%)
#   adding: salesforce_images/e5e631c58bb6b5549ce44d251ef2e98a.jpg (deflated 1%)
#   adding: salesforce_images/c87efa653104ecff99d58817f5e8d24e.jpg (deflated 4%)
#   adding: salesforce_images/83cdd29725a50573a7ebae8072862dab.jpg (deflated 2%)
#   adding: salesforce_images/b2a19d8cfba5e2f82cb2b956098fb204.jpg (deflated 8%)
#   adding: salesforce_images/1040c625d5f48640077ca9cbb075ca73.jpg (deflated 1%)
#   adding: salesforce_images/4ed234bf504414deeb78bf62283cb95d.jpg (deflated 0%)
#   adding: salesforce_images/0e9e2dea35558ed49464a63808552606.jpg (deflated 2%)
#   adding: salesforce_images/9572a6a874c2a0e57513059905a369c1.jpg (deflated 1%)
#   adding: salesforce_images/2d79dfbd5e93be906b9fa611b76ca3e2.jpg (deflated 5%)
#   adding: salesforce_images/304ab8a8a931b663d90c1ad0782b7c83.jpg (deflated 3%)
#   adding: salesforce_images/0f84a572a90b8305eebd4c176a9b7f7a.jpg (deflated 0%)
#   adding: salesforce_images/468c869be1289d6dc716bfb862a35a03.jpg (deflated 17%)
#   adding: salesforce_images/9c1576f3604cb503081ca7c3c358c08b.jpg (deflated 0%)
#   adding: salesforce_images/c65a498651aa154f73226b4aae493b75.jpg (deflated 2%)
#   adding: salesforce_images/a6fbbe1003addb5367c2f53f67f6202f.jpg (deflated 6%)
#   adding: salesforce_images/a49de8b5e81101715f66774da790ac38.jpg (deflated 13%)
#   adding: salesforce_images/366c22151f3aa2e9f366c27890f38eb1.jpg (deflated 11%)
#   adding: salesforce_images/cc02f8a047e9461c3a4a8fcd922af509.jpg (deflated 4%)
#   adding: salesforce_images/891895eccca58c24106db0863098779f.jpg (deflated 2%)
#   adding: salesforce_images/a869de9f70c69a196eec3c7a317d1cfb.jpg (deflated 15%)
#   adding: salesforce_images/695073eaa282ddd67660a21c0af21cbe.jpg (deflated 0%)
#   adding: salesforce_images/1ae8d21ba9975683a31b0a9363900be8.jpg (deflated 2%)
#   adding: salesforce_images/5f9209ebe12c186a358a63f03fe4cb45.jpg (deflated 1%)
#   adding: salesforce_images/97750533587c74f870de94a437561a3a.jpg (deflated 1%)
#   adding: salesforce_images/0af25029f56d7856e9c9260755058d31.jpg (deflated 1%)
#   adding: salesforce_images/4481081a11f05133715ae4e1d5958e15.jpg (deflated 2%)
#   adding: salesforce_images/b4ecf2bb6bf315a9b0ad1a3ae56c9e81.jpg (deflated 3%)
#   adding: salesforce_images/be93467161021a08d6f9a6f02fcb286a.jpg (deflated 1%)
#   adding: salesforce_images/326e89adc86d1dcb6360edc3ecb11e76.jpg (deflated 1%)
#   adding: salesforce_images/ebe3a712e1322a858cbd84dc450218a5.jpg (deflated 0%)
#   adding: salesforce_images/aab2d60da3c73ab5188f3602b9ca0900.jpg (deflated 9%)
#   adding: salesforce_images/09392af499af053443984921fb647824.jpg (deflated 3%)
#   adding: salesforce_images/5c174412020e9088986604f93aaf8466.jpg (deflated 1%)
#   adding: salesforce_images/803550ab941860a47ba546d129bebb83.jpg (deflated 14%)
#   adding: salesforce_images/f4c2c9f772d79d683c57339a037dc4eb.jpg (deflated 2%)
#   adding: salesforce_images/e85b2d85c3316d4dd097cad6b1859340.jpg (deflated 1%)
#   adding: salesforce_images/649a30a296ea22f2a2f56a36881ffb3a.jpg (deflated 23%)
#   adding: salesforce_images/73249d328e795720efe2a74c89ad552e.jpg (deflated 2%)
#   adding: salesforce_images/de29497fb05509f1c997d9b353830219.jpg (deflated 1%)
#   adding: salesforce_images/107b607d0a910536c8a6d1fac9db574a.jpg (deflated 6%)
#   adding: salesforce_images/3717a940da49781afc45cf7826f756e2.jpg (deflated 6%)
#   adding: salesforce_images/b6f65cb0dc3f78f03a6fe317527dcc08.jpg (deflated 10%)
#   adding: salesforce_images/8d8ef1992c18e607d9c0524a61f2763b.jpg (deflated 1%)
#   adding: salesforce_images/b9d5844af9216c8fc70b2a1af8e5ac86.jpg (deflated 1%)
#   adding: salesforce_images/68618a9bedf338952dd6c1ec3bf632b1.jpg (deflated 2%)
#   adding: salesforce_images/52181bcd7fddc55db124860a1094efc7.jpg (deflated 0%)
#   adding: salesforce_images/a23d5c69720e377a80822424e723f1b4.jpg (deflated 0%)
#   adding: salesforce_images/a2b945474bd889cfa3a403a8060c87d5.jpg (deflated 3%)
#   adding: salesforce_images/b14709c7f641ef6889c981a442ebad86.jpg (deflated 1%)
#   adding: salesforce_images/bfb7cfdb1269e59cad129c72124df5f1.jpg (deflated 2%)
#   adding: salesforce_images/f39a28a598e9f68317cd5780e0b4bc63.jpg (deflated 3%)
#   adding: salesforce_images/f103e220f654ff9c59b963fe1b90d31d.jpg (deflated 13%)
#   adding: salesforce_images/e82d69c1e1b3bc6b678165b201500fdb.jpg (deflated 1%)
#   adding: salesforce_images/ad6ea2776ea8f4260e09bd1f8336f787.jpg (deflated 5%)
#   adding: salesforce_images/bc4f66ad15d34c6a1ad4cc57bc1a00bd.jpg (deflated 6%)
#   adding: salesforce_images/1d60dc4061cb8e1c2012d2b9d2a01223.jpg (deflated 2%)
#   adding: salesforce_images/932687b10ec7d422bfe363c57d2c5b0a.jpg (deflated 2%)
#   adding: salesforce_images/fd62c0151d47827741bb5ac1b9aa71b8.jpg (deflated 1%)
#   adding: salesforce_images/c80cd4e0f94428dbaa21bd9f039e0cc5.jpg (deflated 2%)
#   adding: salesforce_images/ad9291428c85f1a9bab063bc4dae64c3.jpg (deflated 2%)
#   adding: salesforce_images/1c5f6ec6797b3649a2c4253f9076876f.jpg (deflated 5%)
#   adding: salesforce_images/d20b8792ec28ddc25161bfe467cd8102.jpg (deflated 5%)
#   adding: salesforce_images/4e885177a8dcdb5d9fa13c5d8ea17514.jpg (deflated 3%)
#   adding: salesforce_images/05ae9fc609776bc7c30117fbca6227db.jpg (deflated 2%)
#   adding: salesforce_images/1a83c70101e722256e16b19fec30b9fd.jpg (deflated 2%)
#   adding: salesforce_images/5559e011e2af38f7dce6e27c6f94040d.jpg (deflated 2%)
#   adding: salesforce_images/8be5ce397e7cb0199a6cc110b77f8013.jpg (deflated 8%)
#   adding: salesforce_images/1b310d03314d1e85a66080f86a7293e2.jpg (deflated 4%)
#   adding: salesforce_images/e702ed495440a36c75e0ac533b132c6b.jpg (deflated 8%)
#   adding: salesforce_images/97c8def771abbb5922cf02c94cb6397e.jpg (deflated 6%)
#   adding: salesforce_images/ddf209a1326f069ced419850ce8b6283.jpg (deflated 3%)
#   adding: salesforce_images/204a477ccea026707c315cf7182fe046.jpg (deflated 5%)
#   adding: salesforce_images/d2d318ac57d17f12a429b4e053b9dec9.jpg (deflated 1%)
#   adding: salesforce_images/d84a49d88047b0a7c57c6049402d70be.jpg (deflated 0%)
#   adding: salesforce_images/7e2d1d1ab107e9e79db92b7c917e9c34.jpg (deflated 5%)
#   adding: salesforce_images/434f610b6dd01efd99d16a1fbc2cd505.jpg (deflated 4%)
#   adding: salesforce_images/08fb1e7e749ed8855bceaedb951f307d.jpg (deflated 14%)
#   adding: salesforce_images/e92d884e3c2172f67cb244ee17dc75f8.jpg (deflated 22%)
#   adding: salesforce_images/d04920507f6afcb7ac97c59e4fa121a8.jpg (deflated 11%)
#   adding: salesforce_images/8b3382da27b8ac6cf5052a532037c060.jpg (deflated 3%)
#   adding: salesforce_images/80e49a6774e7bc8494843349955b5bd0.jpg (deflated 1%)
#   adding: salesforce_images/f87bd65556bba9e5dd0a197db2b13891.jpg (deflated 1%)
#   adding: salesforce_images/2c1045200338532b851faf984b2d5061.jpg (deflated 11%)
#   adding: salesforce_images/7a2854db66de962582e417aefc978b69.jpg (deflated 1%)
#   adding: salesforce_images/2a98f4b2f655a1735b77a65277ce8460.jpg (deflated 10%)
#   adding: salesforce_images/a0c8c48438f9046150389314128dd005.jpg (deflated 4%)
#   adding: salesforce_images/fd1387147dd97f9ed83629893b3e8c1d.jpg (deflated 1%)
#   adding: salesforce_images/f58e10a0324c674b89b76cf98b8c007e.jpg (deflated 2%)
#   adding: salesforce_images/e9d731252ee559ae60c5c0548471d697.jpg (deflated 1%)
#   adding: salesforce_images/37b3e57a790447dbc5ca3489c6b22693.jpg (deflated 1%)
#   adding: salesforce_images/9726f87b9b4c8a5eb801fea7a093be73.jpg (stored 0%)
#   adding: salesforce_images/59128840bf44336c67301e0097d936b6.jpg (deflated 1%)
#   adding: salesforce_images/145d16a931a69e7cbedab46860afb7a5.jpg (deflated 7%)
#   adding: salesforce_images/17de943a438762d1529b1eab370f16c1.jpg (deflated 0%)
#   adding: salesforce_images/a46f8c82048ee17839ce718476a3736e.jpg (deflated 4%)
#   adding: salesforce_images/c1047c57ba9ae49fc1c91ff6729d6ee0.jpg (deflated 1%)
#   adding: salesforce_images/3fa6b7e32bf25d1066c903d7e9b6c4c4.jpg (deflated 2%)
#   adding: salesforce_images/5d3aa98c48a882b128b43c6726b96b3e.jpg (deflated 3%)
#   adding: salesforce_images/0332a242434b46e94ff71d6f866a47f0.jpg (deflated 4%)
#   adding: salesforce_images/08feceeb103760c2a99768804b9b7685.jpg (deflated 1%)
#   adding: salesforce_images/8ef3376385f1eb365a0e2f600799c61c.jpg (deflated 4%)
#   adding: salesforce_images/e34366711a83a3b6f9902ccf7143066e.jpg (deflated 2%)
#   adding: salesforce_images/491f853596aefbfbf9264054791cd60e.jpg (deflated 1%)
#   adding: salesforce_images/ddaec54ebcad46b4b6342deaf130dcda.jpg (deflated 11%)
#   adding: salesforce_images/5b20861593b915a2de260079b7f75429.jpg (deflated 6%)
#   adding: salesforce_images/2c969b1b36669b17abcf81a57fcc778a.jpg (deflated 19%)
#   adding: salesforce_images/a1f22acaa135187e78298fce86712109.jpg (deflated 10%)
#   adding: salesforce_images/cc31d68eb25f157c39144921c30cd3ab.jpg (deflated 2%)
#   adding: salesforce_images/f6201cb88360da361f440aff386e4554.jpg (deflated 3%)
#   adding: salesforce_images/497519e67c6b2df986c615ba0cb28de4.jpg (deflated 4%)
#   adding: salesforce_images/dc01344f60efb5ccde84a0aa20b08b85.jpg (deflated 1%)
#   adding: salesforce_images/25b8637ea6d16764d44ade6bd9ad34a8.jpg (deflated 3%)
#   adding: salesforce_images/ccdf89dd168a669395f1441a8dfcecbc.jpg (deflated 35%)
#   adding: salesforce_images/7b58006eec34b50bae7e7a27850d593f.jpg (deflated 3%)
#   adding: salesforce_images/3f4f22031ac5a370cfb42ad29cf66b32.jpg (deflated 42%)
#   adding: salesforce_images/b3ed18aadd39e4ca49b7debc8a430c53.jpg (deflated 2%)
#   adding: salesforce_images/74ea49016809cf1a10cf2ba7f18286a4.jpg (deflated 4%)
#   adding: salesforce_images/ae3113431c85a28bf4d8877089348662.jpg (deflated 0%)
#   adding: salesforce_images/2d12d3a65471d377a64666c41030c14e.jpg (deflated 2%)
#   adding: salesforce_images/b2d5d94aee2e0564ea5a19b87a07a9fe.jpg (deflated 0%)
#   adding: salesforce_images/40d700ba1221c62fb392c8b4853d12bf.jpg (deflated 3%)
#   adding: salesforce_images/a334327590be4fc339993dfe91aa08d5.jpg (deflated 0%)
#   adding: salesforce_images/46c29ea9243ad2281578c377355de5ab.jpg (deflated 5%)
#   adding: salesforce_images/6dd44d5edf9af98637818f986d759a17.jpg (deflated 6%)
#   adding: salesforce_images/dd950fca3bbb01bc592ebef223efcf59.jpg (deflated 1%)
#   adding: salesforce_images/3b502242b1eefe1b11dbaa56cbf2579b.jpg (deflated 3%)
#   adding: salesforce_images/3c12c61dc852f4b1e2ac33ae01956701.jpg (deflated 1%)
#   adding: salesforce_images/98cf4ead453c44cb01a204a450150300.jpg (deflated 22%)
#   adding: salesforce_images/755990e2f529a3315e640d278f44d63f.jpg (deflated 0%)
#   adding: salesforce_images/37f4d5bc27b0781313af4173151cfb56.jpg (deflated 4%)
#   adding: salesforce_images/fbd04892a3fabc25306e6874b7806a9d.jpg (deflated 21%)
#   adding: salesforce_images/d775cf14f3ea7f460f9bb797de814e2a.jpg (deflated 2%)
#   adding: salesforce_images/17d525dc5aa3f6e61c809eea85b72351.jpg (deflated 3%)
#   adding: salesforce_images/9fd4f966ae91348c0c30120f454c0020.jpg (deflated 3%)
#   adding: salesforce_images/ae6dec2367d31bb170aa38523a91cf6c.jpg (deflated 5%)
#   adding: salesforce_images/84afe69797c3c5fed58589972d6a09bf.jpg (deflated 3%)
#   adding: salesforce_images/84f294d3078ac723ca7a548a316dd99f.jpg (deflated 8%)
#   adding: salesforce_images/9b9bf5f8e44b275e4c5fa9fbf50b579c.jpg (deflated 1%)
#   adding: salesforce_images/e336768bb22afcf6d724943279282b08.jpg (deflated 5%)
#   adding: salesforce_images/2c6e6bf035991a0cb4f99decd9b0340d.jpg (deflated 2%)
#   adding: salesforce_images/3614aa636a6614745fb3a3a7c9e28019.jpg (deflated 6%)
#   adding: salesforce_images/fe9fd975b8d589f262e4dafa9e0c3407.jpg (deflated 0%)
#   adding: salesforce_images/2e1f77a3b44ec4c1ed2247a8a8ffdf90.jpg (deflated 13%)
#   adding: salesforce_images/e5398c0cd68d1fc1bf6bdd85d2cebac2.jpg (deflated 2%)
#   adding: salesforce_images/7d1ffe5d7fdbb57f281e970e44441ee2.jpg (deflated 2%)
#   adding: salesforce_images/0f0ffca546d251e4357da549fa9bec97.jpg (deflated 13%)
#   adding: salesforce_images/80b01c990c516a1d8012095754ad4a33.jpg (deflated 4%)
#   adding: salesforce_images/61429d5b3639e4aec244b587e0e6573c.jpg (deflated 4%)
#   adding: salesforce_images/424dc783138611ce58e71f233b5e8515.jpg (deflated 3%)
#   adding: salesforce_images/bc62ac64fb053dcec1fc2bc42aa2cb90.jpg (deflated 1%)
#   adding: salesforce_images/a9d05b613289459352afa92aecaf8fd3.jpg (deflated 9%)
#   adding: salesforce_images/6125b2ea6b50d361edc7d2ab4e761fe7.jpg (deflated 11%)
#   adding: salesforce_images/35adb74be53cdcbdac94dc40da703fe1.jpg (deflated 5%)
#   adding: salesforce_images/f5ef4958c49d56ae6182bcfed6a6c0cf.jpg (deflated 13%)
#   adding: salesforce_images/c293fa7bceed2c50e9b6fabafb39cad1.jpg (deflated 2%)
#   adding: salesforce_images/bf8ddd6802af5f05d88b69445048c5be.jpg (deflated 1%)
#   adding: salesforce_images/82eaeeb8ddb69e145768e43d54de3ede.jpg (deflated 4%)
#   adding: salesforce_images/2e81ca2ca577d0b52a18f8a1b74d955a.jpg (deflated 11%)
#   adding: salesforce_images/cc684a7f708c7598ec6f231359fd0aed.jpg (deflated 23%)
#   adding: salesforce_images/f6c8a3155b5ba94d81c7d58233d7b89c.jpg (deflated 24%)
#   adding: salesforce_images/6e6d0090bbbe0e6afb1ee6e82f79dce3.jpg (deflated 0%)
#   adding: salesforce_images/b54773cd78099df9d82ff5bbdd8fc380.jpg (deflated 2%)
#   adding: salesforce_images/05cdd21394c0bb892fd3832b172562d3.jpg (deflated 4%)
#   adding: salesforce_images/4bb895c1deea2c4c7969a6b46840b506.jpg (deflated 10%)
#   adding: salesforce_images/3cd692e75164b513a2529641404d9ee9.jpg (deflated 2%)
#   adding: salesforce_images/497a6885de68276966c523df6095db2c.jpg (deflated 5%)
#   adding: salesforce_images/ab84406a31fce9fafc6c2fc4129f1174.jpg (deflated 12%)
#   adding: salesforce_images/fa7be43ed47def2d3e5caf1f480293d5.jpg (deflated 1%)
#   adding: salesforce_images/5bc5e10ec28f9c215b2a6a41056b073a.jpg (deflated 3%)
#   adding: salesforce_images/e27a51757cd1e7edbe13c37fb44db30f.jpg (deflated 2%)
#   adding: salesforce_images/a27d410dfd9ab77b5950bf86bc97a80a.jpg (deflated 1%)
#   adding: salesforce_images/57ea56138269d6def10b37b870db86f0.jpg (deflated 1%)
#   adding: salesforce_images/662c7eae7b24dfd59da6d56b8a765f8d.jpg (deflated 7%)
#   adding: salesforce_images/a8108f7d642cecd0c7a5c5b212c1ca4c.jpg (deflated 0%)
#   adding: salesforce_images/9d3eafe3d56c4b9935cef8116fe3964e.jpg (deflated 1%)
#   adding: salesforce_images/dd395a7858c71a52da3ba5e0f63b960f.jpg (deflated 7%)
#   adding: salesforce_images/84cb316169fe8b8303994c97996e93c1.jpg (deflated 19%)
#   adding: salesforce_images/037fd0d56793e5691f3a5985f5928f0d.jpg (deflated 8%)
#   adding: salesforce_images/90b6af40d43825c8fabe0bc53e008e0f.jpg (deflated 6%)
#   adding: salesforce_images/1207e8ddb8fa77a8376c547807a5edd3.jpg (deflated 3%)
#   adding: salesforce_images/c7e216870055b3c0fb8506e78a0aab8e.jpg (deflated 4%)
#   adding: salesforce_images/0a08016a2333df0b9f99f54c496c7c99.jpg (deflated 8%)
#   adding: salesforce_images/cfd68be349ccddb9b4a8ea08b667a9d2.jpg (deflated 4%)
#   adding: salesforce_images/64258292ff0a2bf8f7f025f7aa22c1d3.jpg (deflated 7%)
#   adding: salesforce_images/a48bca7c192b05a7b680dbce738e7f8e.jpg (deflated 2%)
#   adding: salesforce_images/8bab650673fa16c423e3201b4de5538c.jpg (deflated 5%)
#   adding: salesforce_images/c996a0f6cd2aecc2e3db88dd12c417f2.jpg (deflated 1%)
#   adding: salesforce_images/5eaccb02d00cdcaadd8d4a02c6fbc8de.jpg (deflated 8%)
#   adding: salesforce_images/2753d8a1c3e45f2df740584ef46b173a.jpg (deflated 1%)
#   adding: salesforce_images/fb3062c687e486c63d0edc8083f916e6.jpg (deflated 7%)
#   adding: salesforce_images/171cc6569009fc80a29c3d9b6d216ba4.jpg (deflated 0%)
#   adding: salesforce_images/29d48c81f9a4c8a1ef80f59030843e40.jpg (deflated 7%)
#   adding: salesforce_images/9e99e2ef8fe5eed84e5d57f39ff2c41f.jpg (deflated 5%)
#   adding: salesforce_images/3206015d52e53856e6eb5ab6cd8eb6ec.jpg (deflated 14%)
#   adding: salesforce_images/121e346c8a50777471c4be5e39cf181d.jpg (deflated 13%)
#   adding: salesforce_images/02765a0cc0b060e2959d66b13a47b07b.jpg (deflated 2%)
#   adding: salesforce_images/5e4571315db1451a28a0639a367d8974.jpg (deflated 3%)
#   adding: salesforce_images/8475cf8b2e01945db56950c8510c89e0.jpg (deflated 17%)
#   adding: salesforce_images/8ab28c4c5e6ddb130fb70bd9c9e9bfc8.jpg (deflated 20%)
#   adding: salesforce_images/20f29875425e1974af70b99b00b25cac.jpg (deflated 3%)
#   adding: salesforce_images/ef47b475e3e136c33a27cd37b11a8bcc.jpg (deflated 2%)
#   adding: salesforce_images/f4f95424cf1880ee82993912e6859803.jpg (deflated 4%)
#   adding: salesforce_images/fae0d6357dfeb5e45e4be051ed6422a5.jpg (deflated 4%)
#   adding: salesforce_images/bc51da16b3444998c34e51a5687ea958.jpg (deflated 4%)
#   adding: salesforce_images/d98c10b1b428916b607b6bfd1bd02075.jpg (deflated 8%)
#   adding: salesforce_images/9777de126759fc8fae22653f1c44c5db.jpg (deflated 11%)
#   adding: salesforce_images/4efb337fde3c058194ca814de5790cae.jpg (deflated 1%)
#   adding: salesforce_images/cbb1a69364d4fe8bf7bac9acdd65afd3.jpg (deflated 2%)
#   adding: salesforce_images/d6ae5b67eda73e256167871a79c71e8a.jpg (deflated 12%)
#   adding: salesforce_images/17825e0677f2dc4850990cd832324c49.jpg (deflated 1%)
#   adding: salesforce_images/f1cabfd4609e2c3b6a94897daeed4e25.jpg (deflated 13%)
#   adding: salesforce_images/e03ffda4018346bb5b09dcc894eac260.jpg (deflated 1%)
#   adding: salesforce_images/1d63766bf48ef0005a28ca739ba0fa46.jpg (deflated 10%)
#   adding: salesforce_images/f7dc1234995114d68a27bccebf5fe479.jpg (deflated 8%)
#   adding: salesforce_images/f21b1a150a4d4b6f1c452a78eb7e7f53.jpg (deflated 2%)
#   adding: salesforce_images/e217d7b56e063e80e6994c7594591565.jpg (deflated 2%)
#   adding: salesforce_images/18276991aaab8aeacbf540f66699d20b.jpg (deflated 10%)
#   adding: salesforce_images/9b9d0791c17852473cfaf7c514524c41.jpg (deflated 9%)
#   adding: salesforce_images/ca0955500cb5a7e69d18e0064fa4d426.jpg (deflated 14%)
#   adding: salesforce_images/245835eac7e87357b9af6c2f944ee6b4.jpg (deflated 15%)
#   adding: salesforce_images/08d2c60006b77c2d7f3c33ac1a37d959.jpg (deflated 1%)
#   adding: salesforce_images/f0b114f18e35db7a1ab8ffcd6482d3e6.jpg (deflated 2%)
#   adding: salesforce_images/f1b47018992ed73b37ea268bcab4aa3d.jpg (deflated 12%)
#   adding: salesforce_images/56d210de214bacc35b501e8041f09716.jpg (deflated 1%)
#   adding: salesforce_images/b75393a25fee5ece7cff4b72362b9537.jpg (deflated 7%)
#   adding: salesforce_images/89732552a1f340c2fc640dfdf2c72c3d.jpg (deflated 6%)
#   adding: salesforce_images/435929a3a6a0e7671610bf02b9613dda.jpg (deflated 1%)
#   adding: salesforce_images/666cd1f9a40c8dbdd0838eeae7632e5f.jpg (deflated 5%)
#   adding: salesforce_images/9f95e4fdebd2ff6440f034153bb9685a.jpg (deflated 5%)
#   adding: salesforce_images/d88e7cb7059cb4af4ce3a396ebf370a9.jpg (deflated 4%)
#   adding: salesforce_images/88b8c2c5d9c2b7c0b2ccb1fe4c6abbeb.jpg (deflated 1%)
#   adding: salesforce_images/3d3417d00265a7b1c662a1a135c78ad4.jpg (deflated 1%)
#   adding: salesforce_images/4ecb66a9aa2e72385d35ca766914cb72.jpg (deflated 5%)
#   adding: salesforce_images/4531cedf316cc6b7dbc78ddc2cbcb9ab.jpg (deflated 1%)
#   adding: salesforce_images/5c35946890bb597824b6866c7368cbed.jpg (deflated 1%)
#   adding: salesforce_images/c7c5bf0a74b3c39401b8b0bfd0ebf698.jpg (deflated 11%)
#   adding: salesforce_images/93b510e51f13dd03191ccd0b63e830b9.jpg (deflated 3%)
#   adding: salesforce_images/a47364c11f0106929b196d27468d54a2.jpg (deflated 5%)
#   adding: salesforce_images/8e89b75b3fa0b045d9ea3c0ff9ea932c.jpg (deflated 2%)
#   adding: salesforce_images/5d85f7dac7cfa3543e1b57add99c7505.jpg (deflated 2%)
#   adding: salesforce_images/81cfebffd3d24837ee453793babdcfa1.jpg (deflated 2%)
#   adding: salesforce_images/4c44e00c9737ccea3a80d6548ea4f707.jpg (deflated 7%)
#   adding: salesforce_images/f5fce68b7c6be9be0b19d8ac35651aa1.jpg (deflated 8%)
#   adding: salesforce_images/b46a88b809508dcebdbb29a4b81e491b.jpg (deflated 25%)
#   adding: salesforce_images/fdd48af8d10f47595d7a887a559a83db.jpg (deflated 8%)
#   adding: salesforce_images/768c9abc2ebc0e2bc9dded4a3ad2a530.jpg (deflated 2%)
#   adding: salesforce_images/44ad2dc7db8fbd7ea413934dfc5d95c1.jpg (deflated 4%)
#   adding: salesforce_images/5375fb47243a1ec34d6fd92042f92da8.jpg (deflated 2%)
#   adding: salesforce_images/17d4b34d1c571b71074b77e171006c96.jpg (deflated 12%)
#   adding: salesforce_images/035693421696afa41dc1418b70ff3ec2.jpg (deflated 5%)
#   adding: salesforce_images/8c3a36d236ad0cbe84041d42c3c8107b.jpg (deflated 0%)
#   adding: salesforce_images/53e9c488e4397ca617af1a990c38b316.jpg (deflated 0%)
#   adding: salesforce_images/6e88c1f511c181e06937841361fd3a44.jpg (deflated 3%)
#   adding: salesforce_images/ba0beff5c0bcef1532308e151bf6a8c5.jpg (deflated 3%)
#   adding: salesforce_images/b59ebd9aa81da9a59d9298083ed7812d.jpg (deflated 2%)
#   adding: salesforce_images/762bfd225044e3802b23ee5d446f6af3.jpg (deflated 3%)
#   adding: salesforce_images/4633bdd09b91229de452a71c12411ef6.jpg (deflated 2%)
#   adding: salesforce_images/af9a5be050718ef30af3e4ad21681a31.jpg (deflated 1%)
#   adding: salesforce_images/f55d4da86339a703b7a55c77df483273.jpg (deflated 1%)
#   adding: salesforce_images/dcdea4c3c8b1a49dfcc6eec891fb04e8.jpg (deflated 3%)
#   adding: salesforce_images/7bd317b4d90910206904624a234934a8.jpg (deflated 1%)
#   adding: salesforce_images/0367e48844d7164192c2aa065c5a0674.jpg (deflated 3%)
#   adding: salesforce_images/9417a37a693657ce006466958be37628.jpg (deflated 2%)
#   adding: salesforce_images/81d5b56d2136dbdfd9463bbe1ce9b7b8.jpg (deflated 0%)
#   adding: salesforce_images/2ad71515c86135ace130435167660d88.jpg (deflated 27%)
#   adding: salesforce_images/1871ef229082f015e318854471b374c7.jpg (deflated 2%)
#   adding: salesforce_images/1493133443d690475a7638e9f52067a0.jpg (deflated 3%)
#   adding: salesforce_images/444bbc60d5ae008bf9adf0a8090d844d.jpg (deflated 2%)
#   adding: salesforce_images/8fef14d06a7127a56ca978f3f1cbd748.jpg (deflated 5%)
#   adding: salesforce_images/4fe6a528e4a5724c7886261fa2012abf.jpg (deflated 0%)
#   adding: salesforce_images/09afb181c147fed08be8e91d05d5844f.jpg (deflated 4%)
#   adding: salesforce_images/511a33794173564ae0d4a444694cca07.jpg (deflated 1%)
#   adding: salesforce_images/0f9be24d5e9e9bed2c591284a5faca26.jpg (deflated 7%)
#   adding: salesforce_images/2772ad985ca3a105dabe35ec38c3f83f.jpg (deflated 5%)
#   adding: salesforce_images/884f9a1564fb36a32f6487be47f168b5.jpg (deflated 20%)
#   adding: salesforce_images/8fdba3a3bcb1c0c801df630b82fd11f5.jpg (deflated 2%)
#   adding: salesforce_images/2cc4aa1b42bdbd6acb93fd22917b9cdb.jpg (deflated 1%)
#   adding: salesforce_images/3e3c80627bbfc123ea9cbcba957baacb.jpg (deflated 7%)
#   adding: salesforce_images/235482c1d03ffc1e6d0bd1fc63677de8.jpg (deflated 1%)
#   adding: salesforce_images/a2482c3f1b000ea71e10d23ebbcf4c64.jpg (deflated 15%)
#   adding: salesforce_images/b0532c1cc6ad989f4ccd907d19911c51.jpg (deflated 6%)
#   adding: salesforce_images/ad803f49b6d96d68fbb91674d2824aef.jpg (deflated 1%)
#   adding: salesforce_images/367dca4842beb89993edae81b242b834.jpg (deflated 4%)
#   adding: salesforce_images/eb4dec51e9d2f25095976055a05eb9f5.jpg (deflated 3%)
#   adding: salesforce_images/ab63dc9d6889b44f6167206ffae9d419.jpg (deflated 0%)
#   adding: salesforce_images/24a473e500c71118bf5102559ea8c686.jpg (deflated 32%)
#   adding: salesforce_images/cb24976623cdf83c27a9d43858a8f663.jpg (deflated 1%)
#   adding: salesforce_images/f716e380d7bd992a8bc2e674aa63402c.jpg (deflated 0%)
#   adding: salesforce_images/bb00d15db5ff72e0af4b0ceec9823f69.jpg (deflated 4%)
#   adding: salesforce_images/8399440eccfca3023ccffa8d90406c5e.jpg (deflated 10%)
#   adding: salesforce_images/40754fb36f42af982c046d6934a244ce.jpg (deflated 3%)
#   adding: salesforce_images/6b90ce64538833161d55e79d42a1d5f3.jpg (deflated 16%)
#   adding: salesforce_images/1813849189b06911cc1eb2599972c25d.jpg (deflated 1%)
#   adding: salesforce_images/b1fcdf8f12f26cad3c84af70046aef26.jpg (deflated 3%)
#   adding: salesforce_images/6ca2bc46ebe2747fb80c97b0f1335fc6.jpg (deflated 1%)
#   adding: salesforce_images/224c063a2a449a54d0deb13aae973cde.jpg (deflated 1%)
#   adding: salesforce_images/14a302ce10b6d821c49458cb30bc0b9a.jpg (deflated 0%)
#   adding: salesforce_images/912702962e75ba90ece507b2ff6c8a1e.jpg (deflated 3%)
#   adding: salesforce_images/9d1b2a0c575f8316e1f428313823618a.jpg (deflated 2%)
#   adding: salesforce_images/6cb2880d07032f17ddc74db6a5496073.jpg (deflated 9%)
#   adding: salesforce_images/547091baf840926b0d85f951fca3431b.jpg (deflated 5%)
#   adding: salesforce_images/7c9b465b6600ee4bbc177209cf487a3f.jpg (deflated 3%)
#   adding: salesforce_images/c17d592b7ecf03e7f6c1996cee43511a.jpg (deflated 12%)
#   adding: salesforce_images/47b9e1e215b27cf4e01eefc730dfcf6c.jpg (deflated 1%)
#   adding: salesforce_images/2b64526ec8bb540d52fee4baac1bd12b.jpg (deflated 6%)
#   adding: salesforce_images/b37282770d96f72205d08a02536499d4.jpg (deflated 5%)
#   adding: salesforce_images/d419a5710cceffa3be81b51646f8e5ad.jpg (deflated 2%)
#   adding: salesforce_images/942b84565baf0048ae4d6a33adb8b97f.jpg (deflated 1%)
#   adding: salesforce_images/0cd74c831db13254412dc21db5277b74.jpg (deflated 0%)
#   adding: salesforce_images/9e481494ebccaac8b1cf446ef07e106e.jpg (deflated 11%)
#   adding: salesforce_images/727e3e994781139fbbde72e29d1e17c4.jpg (deflated 2%)
#   adding: salesforce_images/56c772cff8253ff0362fa13709ce54bd.jpg (deflated 23%)
#   adding: salesforce_images/b0b45213863a9152d4889e650ef4ece7.jpg (deflated 4%)
#   adding: salesforce_images/2342db1d9c0e6124939ee2ca9ca6a18c.jpg (deflated 1%)
#   adding: salesforce_images/ad3dc3efc90b25527b565194cbd73018.jpg (deflated 22%)
#   adding: salesforce_images/b7711fd873a60fb5c5c2baa236e92b41.jpg (deflated 2%)
#   adding: salesforce_images/d15c4e3a123e9899a452c8b9aff204a5.jpg (deflated 2%)
#   adding: salesforce_images/da4d9dacb2bd383df124325f1cd2c5d8.jpg (deflated 0%)
#   adding: salesforce_images/71474f9b30822ef037f58ad27afb4533.jpg (deflated 7%)
#   adding: salesforce_images/b50fc27ac78aead94e5d26d372327fbb.jpg (deflated 9%)
#   adding: salesforce_images/bc98399446367afd364315bb802f0c04.jpg (deflated 17%)
#   adding: salesforce_images/222e2de5e6779d4d9822b719b89661b3.jpg (deflated 34%)
#   adding: salesforce_images/39a4fceef5de84449d275d3a9e12aa90.jpg (deflated 3%)
#   adding: salesforce_images/9950544cd5a74a426d9126f3c2fe8d54.jpg (deflated 7%)
#   adding: salesforce_images/e26b9a01747d69a0b0ecd25bca3363de.jpg (deflated 8%)
#   adding: salesforce_images/90307c41206830bcd94a0f30bdd1ebb2.jpg (deflated 1%)
#   adding: salesforce_images/962b3d02f1b5078552840851f5e680f7.jpg (deflated 5%)
#   adding: salesforce_images/9309e3aeff68edc35f9d654d323e87a8.jpg (deflated 2%)
#   adding: salesforce_images/2395d44a1c660b52002af46dc6526748.jpg (deflated 9%)
#   adding: salesforce_images/1529ebe6a748cbeec58bd357862363ce.jpg (deflated 8%)
#   adding: salesforce_images/9ef55b6e1709b748451bf5c02411daaf.jpg (deflated 3%)
#   adding: salesforce_images/2beed5c7326b6f6a67870ed08fbd455a.jpg (deflated 30%)
#   adding: salesforce_images/5874d8e95de3f0b55c35b39a7938713c.jpg (deflated 7%)
#   adding: salesforce_images/2856587ef426f8c97e453a669e60eb85.jpg (deflated 2%)
#   adding: salesforce_images/79771904f10fd4bcf275afbebde4bb15.jpg (deflated 11%)
#   adding: salesforce_images/9868fac00a62d1fc13297889ce4c3233.jpg (deflated 17%)
#   adding: salesforce_images/2332ba548752747e6503060cc7fc0b62.jpg (deflated 4%)
#   adding: salesforce_images/2cdaf6174bbc051b85ebe3f66863b46c.jpg (deflated 6%)
#   adding: salesforce_images/5ecec10fbf370f3d1e42e694f62e4928.jpg (deflated 7%)
#   adding: salesforce_images/2f6ebd6c649ad677e894084aa6d89f41.jpg (deflated 8%)
#   adding: salesforce_images/4c61d4ff268c428cc7a3c130bc406c5e.jpg (deflated 1%)
#   adding: salesforce_images/72148630d3e67d470bb4352313470655.jpg (deflated 2%)
#   adding: salesforce_images/9c88bbd723ee32fa51df3e6bbdb419dc.jpg (deflated 2%)
#   adding: salesforce_images/5a0146f8444be551d851ec1e79385159.jpg (deflated 0%)
#   adding: salesforce_images/7d2ed47b1b04f5a24215a4b197d5b1bd.jpg (deflated 0%)
#   adding: salesforce_images/8d3d6d4671cfdb715ef35dd4fa0c1cf5.jpg (deflated 12%)
#   adding: salesforce_images/a93d16f683672a46c3962fd40dc9bc93.jpg (deflated 2%)
#   adding: salesforce_images/515f446cb37ac7b4ca0be3aaf839d09b.jpg (deflated 59%)
#   adding: salesforce_images/97b19174e77ba164becbbaea0449a523.jpg (deflated 6%)
#   adding: salesforce_images/a2e0bf9699321838a52c75152ce53085.jpg (deflated 14%)
#   adding: salesforce_images/d2583ae0e9308ff0857ad906c8fa48f6.jpg (deflated 1%)
#   adding: salesforce_images/5723a9b32926612917eec169e6a67f5d.jpg (deflated 2%)
#   adding: salesforce_images/398ba00e824eeae2931d459b893724fa.jpg (deflated 5%)
#   adding: salesforce_images/070c758f46c0b00d252ec607489853be.jpg (deflated 14%)
#   adding: salesforce_images/fc9fdb412834f8be4414563e68914aaf.jpg (deflated 4%)
#   adding: salesforce_images/fd4d5264ecb76895733ae871916f9e33.jpg (deflated 2%)
#   adding: salesforce_images/1c13d9f9df75a2cd2ebb418eb7a7c5b4.jpg (deflated 34%)
#   adding: salesforce_images/062e9dc261738fe768ba38f3d8ab06e2.jpg (deflated 0%)
#   adding: salesforce_images/43c73e6cef746b75a3e044130af9bf59.jpg (deflated 4%)
#   adding: salesforce_images/0027563292d7308c490fe7a37ef0d30e.jpg (deflated 3%)
#   adding: salesforce_images/e6e83958e2a3ccdb1d6359535b61bee5.jpg (deflated 4%)
#   adding: salesforce_images/a8fa54cc105f098f228dda7f6b88d4ca.jpg (deflated 4%)
#   adding: salesforce_images/4e19cd51e5c73fcb6380d4730ebc24a7.jpg (deflated 23%)
#   adding: salesforce_images/881c7916f76e8457e289a03d48f796b8.jpg (deflated 1%)
#   adding: salesforce_images/fcdabd086209d3a80f8905e83315f7d0.jpg (deflated 0%)
#   adding: salesforce_images/ccdd83ec4dcb7266abf15160d5428baf.jpg (deflated 18%)
#   adding: salesforce_images/db65298a5df4bd836346ba7351e09eab.jpg (deflated 4%)
#   adding: salesforce_images/01f1449f41e582a7879a20bd427d5f64.jpg (deflated 2%)
#   adding: salesforce_images/3c62d17b7f0119db8fd469d4fd031860.jpg (deflated 5%)
#   adding: salesforce_images/1d3a46144b717d922aefd2bf823b573a.jpg (deflated 1%)
#   adding: salesforce_images/96e156cacbd51cb89f8b53687b6cebcc.jpg (deflated 2%)
#   adding: salesforce_images/cdda2299b02b200866da2ca3e678aef4.jpg (deflated 3%)
#   adding: salesforce_images/ef03edf6bab0947297c38e6bba834639.jpg (deflated 3%)
#   adding: salesforce_images/45c3c56c698348ce2b7654ce77b4fdad.jpg (deflated 6%)
#   adding: salesforce_images/28fbfb697fe4b99f0d80faf2c9763d8f.jpg (deflated 1%)
#   adding: salesforce_images/037fc848b7b92df450209df1c2d5ec6c.jpg (deflated 4%)
#   adding: salesforce_images/847237e83e62be03213cf53e2892c061.jpg (deflated 26%)
#   adding: salesforce_images/962176383a5e2279418390b233a478d3.jpg (deflated 1%)
#   adding: salesforce_images/0bd2c1a7e78140a04ae2624365e26916.jpg (deflated 2%)
#   adding: salesforce_images/83680d8d945aa91e532dd603c4e09579.jpg (deflated 2%)
#   adding: salesforce_images/a8d2901b392374ef2b19992a1749939d.jpg (deflated 6%)
#   adding: salesforce_images/996b13af6b0325418d27c467b951f460.jpg (deflated 1%)
#   adding: salesforce_images/04640d00a75703ec6dbc4b54c647497e.jpg (deflated 4%)
#   adding: salesforce_images/1185157a609b9c0e38eb70423c89d7d7.jpg (deflated 5%)
#   adding: salesforce_images/1614502b02de9ad129416c07ca6f7791.jpg (deflated 12%)
#   adding: salesforce_images/51e690564072f893d30e4eeeeb055b96.jpg (deflated 0%)
#   adding: salesforce_images/6747ea19fcfd0d01c200b8b35fba9c2b.jpg (deflated 2%)
#   adding: salesforce_images/6cf279c088a50f8fd90ed67e806a04d5.jpg (deflated 1%)
#   adding: salesforce_images/1eebfe19161abaaa39febdad6f3608c3.jpg (deflated 2%)
#   adding: salesforce_images/a8121eef0e4de62b54a38bf24950481a.jpg (deflated 2%)
#   adding: salesforce_images/b28a1085540f86442d7b2628044c18b6.jpg (deflated 2%)
#   adding: salesforce_images/d9e78b27477d7ffeb9e8d5e2e37fa97d.jpg (deflated 3%)
#   adding: salesforce_images/09bf7f876fbec03d1f926afc035446b8.jpg (deflated 1%)
#   adding: salesforce_images/d172d90fe60b9c8a0d62b83000274339.jpg (deflated 2%)
#   adding: salesforce_images/832f4bc05eca30de9bf9a48c6e69bbb9.jpg (deflated 2%)
#   adding: salesforce_images/eb6cf1ef1f87cd9a91a318ca1a18e4ab.jpg (deflated 4%)
#   adding: salesforce_images/e929e58a415a12da31013679f6a72f81.jpg (deflated 47%)
#   adding: salesforce_images/55ac4ca9f39bc1d393bcf54267a655d3.jpg (deflated 2%)
#   adding: salesforce_images/fd954463f4596f9a322d2db98dba948e.jpg (deflated 1%)
#   adding: salesforce_images/e63cdc265c8f9eca5847f685d244251f.jpg (deflated 10%)
#   adding: salesforce_images/d81cea0f02b3fe98c976b4f1b4b774ef.jpg (deflated 8%)
#   adding: salesforce_images/053ece57ec2191d10a106b72667cb2ba.jpg (deflated 4%)
#   adding: salesforce_images/64c9929b6bfce6195436ac59bab89884.jpg (deflated 29%)
#   adding: salesforce_images/b7b1afce5eb64ff2a1fbdeca9484bd27.jpg (deflated 4%)
#   adding: salesforce_images/b88a2771e043c774b9634fad840a4380.jpg (deflated 1%)
#   adding: salesforce_images/56158a74234c9e1b79bdacd44b7bed8a.jpg (deflated 66%)
#   adding: salesforce_images/0b9ecacc541c5a07cea88d9cee892023.jpg (deflated 2%)
#   adding: salesforce_images/71e059ba31b84a20e10d29d043dc26ee.jpg (deflated 0%)
#   adding: salesforce_images/c38199015ac031550b4068beaf180264.jpg (deflated 1%)
#   adding: salesforce_images/3463c606762ca5cd74911ae7f4bc3ffe.jpg (deflated 1%)
#   adding: salesforce_images/802d1e00e1a3e8fb9a4ca08fb672fb14.jpg (deflated 15%)
#   adding: salesforce_images/ae304dd45353f370445588816207315e.jpg (deflated 3%)
#   adding: salesforce_images/a96f0d8b97453be87b5a0ec5d75c75b9.jpg (deflated 21%)
#   adding: salesforce_images/b749e19a56b2156c5a0990ef26210b47.jpg (deflated 1%)
#   adding: salesforce_images/1e5a017aba8a255194d223d7aba21ddd.jpg (deflated 12%)
#   adding: salesforce_images/78e2c252f9b5f7e03d52ebb0e6dae535.jpg (deflated 2%)
#   adding: salesforce_images/7342088f5c4c8d7c6a74c9b001a083bb.jpg (deflated 2%)
#   adding: salesforce_images/db8890a34b7b00d5cf25e0521332089d.jpg (deflated 6%)
#   adding: salesforce_images/288d165a0e8c47549662f1e03df6cec9.jpg (deflated 2%)
#   adding: salesforce_images/4f3e8b6e59c87de4e6b5a444a80f19f1.jpg (deflated 3%)
#   adding: salesforce_images/5802e80dae6229f78fdd1552327ee2b2.jpg (deflated 1%)
#   adding: salesforce_images/2238aa53601146b05c79afc53937de28.jpg (deflated 1%)
#   adding: salesforce_images/2a653f2c20c47e090a1f0114c6190324.jpg (deflated 2%)
#   adding: salesforce_images/fcb9addc65c8caa9845b9c2695a4f8ac.jpg (deflated 3%)
#   adding: salesforce_images/2a8b55ab2ada10b93f9d811300ec413c.jpg (deflated 1%)
#   adding: salesforce_images/c99a8c1348b04d53e2ca704c4d810cbe.jpg (deflated 1%)
#   adding: salesforce_images/93415639605d9d52518f7eb411f9d30a.jpg (deflated 2%)
#   adding: salesforce_images/b53c9b7ed9e17463c86f5e6cb2000a52.jpg (deflated 8%)
#   adding: salesforce_images/28ca292f31354e4eece18af1d52ccf02.jpg (deflated 2%)
#   adding: salesforce_images/b5c5a431fd9299b8b6c980cf910fc4cf.jpg (deflated 11%)
#   adding: salesforce_images/ef23708a24a79d46c4b1d82bdb9481ae.jpg (deflated 11%)
#   adding: salesforce_images/51933aa12e289a589cfbd9667662dc47.jpg (deflated 2%)
#   adding: salesforce_images/79f38a8f40c28aa6fedec6ceecd5a364.jpg (deflated 6%)
#   adding: salesforce_images/98bb8d4270e47d017bf557c956fcd413.jpg (deflated 5%)
#   adding: salesforce_images/8f7e53991c85c0e32685140b0bd3ebda.jpg (deflated 0%)
#   adding: salesforce_images/8b1afd1bc3599787b8562bd8ba7a45ff.jpg (deflated 1%)
#   adding: salesforce_images/ff017418c16965c93a41d971b51310c9.jpg (deflated 4%)
#   adding: salesforce_images/98c31ebf6da03f4626d49afc3aaf4a37.jpg (deflated 6%)
#   adding: salesforce_images/11f90a8f41f59dfdaf612f51f0f30f90.jpg (deflated 0%)
#   adding: salesforce_images/070e2a07adbd4d74e7ecbd7bb6c092b1.jpg (deflated 8%)
#   adding: salesforce_images/f47fbdfd1c89ae9df11d915e6d79a7f1.jpg (deflated 2%)
#   adding: salesforce_images/093d66f0e7ba271bd74dff3cfbae70b6.jpg (deflated 25%)
#   adding: salesforce_images/03741c643ac813c6406e4b8edf294bbe.jpg (deflated 9%)
#   adding: salesforce_images/023c8ab48a23983213999298d44fcdbf.jpg (deflated 2%)
#   adding: salesforce_images/fee276c67f49afe49f8ab83758e03264.jpg (deflated 1%)
#   adding: salesforce_images/1707b051697368150ebe05d0b54013d7.jpg (deflated 4%)
#   adding: salesforce_images/97940e449ec693dca50e265b878a97ba.jpg (deflated 14%)
#   adding: salesforce_images/457647ac6d6e301625b150ee8f495864.jpg (deflated 6%)
#   adding: salesforce_images/9938ca08399970a07609def84ec1b464.jpg (deflated 1%)
#   adding: salesforce_images/b9624645ac037c7583c9b26ad0a1626a.jpg (deflated 1%)
#   adding: salesforce_images/4ece91276a7e1567134ae35dafddbd66.jpg (deflated 6%)
#   adding: salesforce_images/69bd68234d3e15190834085532cfa702.jpg (deflated 9%)
#   adding: salesforce_images/67ec1bef232be7f89bcfb3471c1976c5.jpg (deflated 5%)
#   adding: salesforce_images/84e104ef29e9fad9662fafbe38116114.jpg (deflated 16%)
#   adding: salesforce_images/f5d43a32bac3b78d56bcb162950153cb.jpg (deflated 4%)
#   adding: salesforce_images/15d90fed72e415e20b1b0abe8edb3ab2.jpg (deflated 2%)
#   adding: salesforce_images/54c67dcb6f748f2ece885b1e145a15c7.jpg (deflated 9%)
#   adding: salesforce_images/12102991e3d1d0d72307be3aa9891ba2.jpg (deflated 1%)
#   adding: salesforce_images/595d750edead52aa1689fceaedcad847.jpg (deflated 4%)
#   adding: salesforce_images/3c14398a3f7ce0b40ec5a73130df90b1.jpg (deflated 17%)
#   adding: salesforce_images/9bb442ada0a2cbc20ff72564d3ee329f.jpg (deflated 11%)
#   adding: salesforce_images/9c17af7a5ee47a35130b5fa099488568.jpg (deflated 11%)
#   adding: salesforce_images/ccf1ac06f4aa759cfb49fd2f0535f450.jpg (deflated 7%)
#   adding: salesforce_images/c471165f0af6a4668b466f596b097f08.jpg (deflated 13%)
#   adding: salesforce_images/04d55211b4ba420e62817a141c34bbc3.jpg (deflated 8%)
#   adding: salesforce_images/5b8f1139aa9f50ba322ec3f46f5d667a.jpg (deflated 17%)
#   adding: salesforce_images/06c4e559ca874be3a19934d1a95655bd.jpg (deflated 19%)
#   adding: salesforce_images/94f6b547f73de7e410b0645914e3e912.jpg (deflated 12%)
#   adding: salesforce_images/2671cf91ad353b24cbdad5fa8f1ec24a.jpg (deflated 3%)
#   adding: salesforce_images/e082f4410d16f8cd754ddbfaab7e85ce.jpg (deflated 8%)
#   adding: salesforce_images/c126d1bceccf112994f5640dade20e1a.jpg (deflated 3%)
#   adding: salesforce_images/d20ecb7a321ede63622e3c81e7dab26d.jpg (deflated 21%)
#   adding: salesforce_images/0608460c113202ab42afefc057296297.jpg (deflated 1%)
#   adding: salesforce_images/49464a45f6d6153c92ed28da1a01122f.jpg (deflated 2%)
#   adding: salesforce_images/020a628662679a0f04b4b5d6c2a3cffb.jpg (deflated 10%)
#   adding: salesforce_images/a3a6b339ec86c5826e011849884bcd9d.jpg (deflated 13%)
#   adding: salesforce_images/318383d6edf8a12bdd4b6a1d39b16e41.jpg (deflated 1%)
#   adding: salesforce_images/6b8ea3117b3514dfd3cb393202d5387b.jpg (deflated 3%)
#   adding: salesforce_images/d0bf0198a9283fe0c842978449d27a66.jpg (deflated 1%)
#   adding: salesforce_images/dea004d2444b3253ea4a3b432b99f349.jpg (deflated 1%)
#   adding: salesforce_images/6f95a0889ec55ddd348231aa15e69f58.jpg (deflated 7%)
#   adding: salesforce_images/33be6fdce4dec3a2085ec08877c79b34.jpg (deflated 7%)
#   adding: salesforce_images/280f7b12453f7cdee3de759b4dd3c8f6.jpg (deflated 15%)
#   adding: salesforce_images/9c44bf85567cc21769abe059af746c7d.jpg (deflated 9%)
#   adding: salesforce_images/8eb3bf30b2f1faf2398e1642ebda971b.jpg (deflated 3%)
#   adding: salesforce_images/ee0a3cb8496d2674e7bfe6b5a7c9d6f2.jpg (deflated 1%)
#   adding: salesforce_images/537c9c85b1aef9ab85bf7c7876b6d1ed.jpg (deflated 0%)
#   adding: salesforce_images/15600f427e82bf169ea80cdbbcee51e9.jpg (deflated 3%)
#   adding: salesforce_images/68b2385d7727f795b1c27f0197e42a0c.jpg (deflated 2%)
#   adding: salesforce_images/5d01c590e0a7b3ac1e9af5b296a3aa3b.jpg (deflated 4%)
#   adding: salesforce_images/17169ae116475780309b9ddd79b1dffa.jpg (deflated 18%)
#   adding: salesforce_images/bd762e977a62b03baf7e66742558f035.jpg (deflated 0%)
#   adding: salesforce_images/32131a3460a03fd1292b51b057370ce7.jpg (deflated 2%)
#   adding: salesforce_images/11a7c47562090bf78680722f650a4c76.jpg (deflated 2%)
#   adding: salesforce_images/309daa8bb02d07085a1a31602085b8e7.jpg (deflated 4%)
#   adding: salesforce_images/adf1502b95b19414a37f438a18b089fe.jpg (deflated 4%)
#   adding: salesforce_images/beb78e68e1bcbf0ea3432d6f4bf7e881.jpg (deflated 6%)
#   adding: salesforce_images/6975d8a7f3ad98d1344323682952312c.jpg (deflated 10%)
#   adding: salesforce_images/7c82a60d03fb08624081224d34b735b0.jpg (deflated 2%)
#   adding: salesforce_images/6c3a70890898b63a590018149b03fe0e.jpg (deflated 1%)
#   adding: salesforce_images/1e6c9423e0171def6b5616e02157ad3d.jpg (deflated 1%)
#   adding: salesforce_images/dcca92275cc7081cf97c53e5eb9d075e.jpg (deflated 1%)
#   adding: salesforce_images/37371d2d845212ae77f5b037eed55bd8.jpg (deflated 2%)
#   adding: salesforce_images/6a3f36e20da8ee85177e43c87ba607e5.jpg (deflated 8%)
#   adding: salesforce_images/6780c2d0c998d56c96a5b44ab37c706d.jpg (deflated 1%)
#   adding: salesforce_images/f019d39226db0fcb8a185bd28b1aeb3f.jpg (deflated 1%)
#   adding: salesforce_images/76042b3e3f5765143163226ae24c0f33.jpg (deflated 0%)
#   adding: salesforce_images/9befdd211417499df5f04630f18ddbf0.jpg (deflated 1%)
#   adding: salesforce_images/10c29c01825d9fb13bbdd8c10bef804f.jpg (deflated 1%)
#   adding: salesforce_images/7ead30e04cf6d626ccc8f9bbe5585fb2.jpg (deflated 5%)
#   adding: salesforce_images/aeedd68dad87c883f8f073d92f91856e.jpg (deflated 2%)
#   adding: salesforce_images/95a72c6b75b63456d14b91c7c46420ed.jpg (deflated 5%)
#   adding: salesforce_images/cff0a810f1777fe7541399b78934bc8e.jpg (deflated 4%)
#   adding: salesforce_images/d1882d4eddcadb69f12b75df33533478.jpg (deflated 2%)
#   adding: salesforce_images/03f5ca617d923cc0bb723379233cec0a.jpg (deflated 1%)
#   adding: salesforce_images/b8f4459bf6b71ab3c80cfec96febaa9c.jpg (deflated 10%)
#   adding: salesforce_images/550de2f03576b406677bc78a707734e1.jpg (deflated 3%)
#   adding: salesforce_images/47284a7a61b071b04751f36e3621c80f.jpg (deflated 5%)
#   adding: salesforce_images/7a7f91451bf6a1a33839fb473d8fca40.jpg (deflated 2%)
#   adding: salesforce_images/74254460a03e6f36fe164f4382edc1b5.jpg (deflated 1%)
#   adding: salesforce_images/5872a729850008c6b707a196d19f4666.jpg (deflated 4%)
#   adding: salesforce_images/4feffd4400ee03b511087196cbf5f113.jpg (deflated 3%)
#   adding: salesforce_images/e3be885ee6850f9a618bf84db6a32a5c.jpg (deflated 1%)
#   adding: salesforce_images/4faab288b5526c0f891e044e18b3ab80.jpg (deflated 1%)
#   adding: salesforce_images/449a74fd313c37f9bc3a5b3177fb7a15.jpg (deflated 9%)
#   adding: salesforce_images/aeb08327ec4af22632892c45422900e6.jpg (deflated 0%)
#   adding: salesforce_images/e877bd71eb4d46467dbd4a083b137b15.jpg (deflated 1%)
#   adding: salesforce_images/07719bb61410862245ae43c04f2ee25d.jpg (deflated 3%)
#   adding: salesforce_images/8a045f9c6f0d3bfe3b4ef4c680bea337.jpg (deflated 2%)
#   adding: salesforce_images/c696428efec1484482f5d6d401146a81.jpg (deflated 6%)
#   adding: salesforce_images/abfed0f87beee80f98da5b2948f91251.jpg (deflated 1%)
#   adding: salesforce_images/d1b37303e717770dd00b3badce075d1b.jpg (deflated 5%)
#   adding: salesforce_images/fc0bc5b4504db5e40b55ee492247d722.jpg (deflated 11%)
#   adding: salesforce_images/8e1d8240a01ec5f716957b151e54b691.jpg (deflated 1%)
#   adding: salesforce_images/0fe4b8030c61e0d71551f9944decd59b.jpg (deflated 30%)
#   adding: salesforce_images/34bf78c7958e5f23c52442851bdeaabb.jpg (deflated 2%)
#   adding: salesforce_images/7dcf372d8c84c3332201f62ac0608d4f.jpg (deflated 12%)
#   adding: salesforce_images/0ce595ffd9938e8f1259ea38af607b92.jpg (deflated 1%)
#   adding: salesforce_images/f8346b398fc1b27903b6a7c1f14ace7e.jpg (deflated 18%)
#   adding: salesforce_images/ea76c87ecdb08bbc6180d9cc908153f0.jpg (deflated 8%)
#   adding: salesforce_images/3df0f52b2b3ea811291816403a0eeabb.jpg (deflated 1%)
#   adding: salesforce_images/5d9a3942559c1f16c679608fbf695818.jpg (deflated 0%)
# ...
#   adding: salesforce_images/ea3a72613b9a2ba5a83cb684d861cebe.jpg (deflated 1%)
#   adding: salesforce_images/709c415877cbe556f74cf1f98a8773e3.jpg (deflated 1%)
#   adding: salesforce_images/d25b36e04ec3b9e0c747e8801005adfb.jpg (deflated 2%)
#   adding: salesforce_images/0ceef5b2598bfde8718f9537ca2c4783.jpg (deflated 3%)
#   adding: salesforce_images/11682a754a4ef104b5a780f0fe2193bf.jpg (deflated 5%)
#   adding: salesforce_images/f9e17fe0e530369fa6416064444610fe.jpg (deflated 9%)
#   adding: salesforce_images/8c3667cd89f38e10fd0a7e996110a09a.jpg (deflated 1%)
#   adding: salesforce_images/5ae8614423db9bfa7f48b7321c03a5a2.jpg (deflated 1%)
#   adding: salesforce_images/4370ff893f66c213b2561d43a50b2ca6.jpg (deflated 3%)
#   adding: salesforce_images/55940646334de1906e6a47afaf2d1ace.jpg (deflated 1%)
#   adding: salesforce_images/d8ffdb799ad598b2b14c09749d5d4a9a.jpg (deflated 2%)
#   adding: salesforce_images/7af354c3471890fa349a395cdadcf658.jpg (deflated 25%)
#   adding: salesforce_images/5825e11c0f437e033060b3901be23dad.jpg (deflated 1%)
#   adding: salesforce_images/998b971010c6ac4045ba6fde954c771e.jpg (deflated 5%)
#   adding: salesforce_images/c8d783971713ded5404ee3e26061b99b.jpg (deflated 3%)
#   adding: salesforce_images/d8c6a12f9cef4cea918034d44f4733e4.jpg (deflated 6%)
#   adding: salesforce_images/144fb01d8ba1538cd8f919c2f796e4a0.jpg (deflated 2%)
#   adding: salesforce_images/4c7e336a25a3695b3082a5f396d36e62.jpg (deflated 11%)
#   adding: salesforce_images/196afec27110d561e6d3863278b1fd8a.jpg (deflated 1%)
#   adding: salesforce_images/a0d03b346e42ec3fe3ef4053806f5db6.jpg (deflated 1%)
#   adding: salesforce_images/a6a99c8db65cc237c1641d50daf7f51b.jpg (deflated 1%)
#   adding: salesforce_images/e0f9f4ecc1e2f336853f9f63ef3bdb54.jpg (deflated 13%)
#   adding: salesforce_images/e0b094a5c7c24176649495fb73236ee2.jpg (deflated 22%)
#   adding: salesforce_images/6cf61799ac12bb033a26da130139ab68.jpg (deflated 0%)
#   adding: salesforce_images/bd7fe5e28b5f62a4b378df9d843e2710.jpg (deflated 1%)
#   adding: salesforce_images/926544535f45a95aa78f8aa9ec07fc97.jpg (deflated 3%)
#   adding: salesforce_images/f96fba332906e4ea551dc9e070d5cac0.jpg (deflated 2%)
#   adding: salesforce_images/4eb1442bc711b0943517182f75fc7f08.jpg (deflated 2%)
#   adding: salesforce_images/6f40e03f271ac622755162446594de2a.jpg (deflated 20%)
#   adding: salesforce_images/8f599f88f3a400017fca1be53e648673.jpg (deflated 16%)
#   adding: salesforce_images/20f85e54390c19a404b700d3d0a34c6f.jpg (deflated 16%)
#   adding: salesforce_images/5ad35031b7897d91fbbd6caf5901b14b.jpg (deflated 0%)
#   adding: salesforce_images/2eded6e9839133e19ae1dfc7378ac0d9.jpg (deflated 11%)
#   adding: salesforce_images/703cdae67cb9cf521469d592a87212a7.jpg (deflated 11%)
#   adding: salesforce_images/1dae0a0339fe80131883cc49f5d167fb.jpg (deflated 1%)
#   adding: salesforce_images/62e7bb7b8df4f5b78af630e051c83c15.jpg (deflated 7%)
#   adding: salesforce_images/6f48117ec7c4b6fd0955ca54db72c30f.jpg (deflated 13%)
#   adding: salesforce_images/fb9108edca181be62d8d185a7e1e3784.jpg (deflated 2%)
#   adding: salesforce_images/25cefd9b590bc0060afd1763d37b600a.jpg (deflated 4%)
#   adding: salesforce_images/1f61b5b90b2b32b54fb3123b9f77e1bc.jpg (deflated 4%)
#   adding: salesforce_images/36099eb2e7c70144ee2e3e77179db5bb.jpg (deflated 2%)
#   adding: salesforce_images/7489bae2eb6eba3a8736d6f52acc42e9.jpg (deflated 1%)
#   adding: salesforce_images/e0aada1461071da80fddf3dac3767357.jpg (deflated 1%)
#   adding: salesforce_images/0a09f9ca3cb27ab50385ca0326881e17.jpg (deflated 31%)
#   adding: salesforce_images/757b4870859e0197115c8b646546a36c.jpg (deflated 32%)
#   adding: salesforce_images/535b87e260e0eb7b33fdd31af8261d06.jpg (deflated 1%)
#   adding: salesforce_images/401a98b02003d5eea2a15edf5e360780.jpg (deflated 9%)
#   adding: salesforce_images/8d58a0de1becd0ccd13c76f62e8eb892.jpg (deflated 1%)
#   adding: salesforce_images/6edafc3c17c83f519f0bd0e35a76517f.jpg (deflated 6%)
#   adding: salesforce_images/2d1762eb48c84722045df8d32e73ed39.jpg (deflated 12%)
#   adding: salesforce_images/c71a58dc5d8be933af6f82ea315d11e5.jpg (deflated 5%)
#   adding: salesforce_images/89c106c91f5b23fca02fa5902e38504b.jpg (deflated 1%)
#   adding: salesforce_images/7e9efe155056ab3c44dee43a6c77bdb8.jpg (deflated 4%)
#   adding: salesforce_images/e7f9776471f99920360d583f8198b8c9.jpg (deflated 1%)
#   adding: salesforce_images/524b2bd8bae09a6c7a00f446aa686b60.jpg (deflated 7%)
#   adding: salesforce_images/ac95c190be966d77733bde9be032bcbe.jpg (deflated 8%)
#   adding: salesforce_images/e69d291693df2d02f8943b53951bb141.jpg (deflated 1%)
#   adding: salesforce_images/ab3a4967b0995f094e1c4b5a748bb3d1.jpg (deflated 8%)
#   adding: salesforce_images/8e567e53166b4ba3b5093aa6e8504518.jpg (deflated 21%)
#   adding: salesforce_images/917bd86225bfb578b91dce53a52ac13e.jpg (deflated 8%)
#   adding: salesforce_images/8c6aa02228695df19408a2170589ee7c.jpg (deflated 31%)
#   adding: salesforce_images/4db171691a50e3c910ad9f739f207151.jpg (deflated 2%)
#   adding: salesforce_images/a12ea16200c5e692fd31a8c49157cd34.jpg (deflated 1%)
#   adding: salesforce_images/2a4a9018f515760d9355ac070b3a688a.jpg (deflated 2%)
#   adding: salesforce_images/8d1b594ff62a45072923fdab51688afa.jpg (deflated 1%)
#   adding: salesforce_images/57e7904fe22e7962459930d59634443f.jpg (deflated 7%)
#   adding: salesforce_images/abb7eed550676b4a63f3a5108573b411.jpg (deflated 27%)
#   adding: salesforce_images/1cbb80140c93e852d69a627e1d9c7e59.jpg (deflated 4%)
#   adding: salesforce_images/db2804b95f0e41582530eddb23429aa5.jpg (deflated 4%)
#   adding: salesforce_images/b6002a8a249523680c516fafd5e19b97.jpg (deflated 34%)
#   adding: salesforce_images/f0c692c6f75cdc23864a4c87195e076a.jpg (deflated 1%)
#   adding: salesforce_images/b1e0d47df7236e0d738d1f15c904f030.jpg (deflated 4%)
#   adding: salesforce_images/521b16317e9d86427a4a1af036943a70.jpg (deflated 5%)
#   adding: salesforce_images/98ec4bd762d1f7fc50fb323cd71eab38.jpg (deflated 9%)
#   adding: salesforce_images/f44d4c8101d1ea3e74190b2539c50063.jpg (deflated 10%)
#   adding: salesforce_images/f9016ba31cc665c2ba3ceea215b91ae9.jpg (deflated 1%)
#   adding: salesforce_images/9f0a4d5834fdad9bc2299e5a7b08f7ef.jpg (deflated 2%)
#   adding: salesforce_images/1b383fccb8b32752531c3a97d1345855.jpg (deflated 8%)
#   adding: salesforce_images/046ca947460eb7a18bb5e986ff6f187a.jpg (deflated 7%)
#   adding: salesforce_images/8e6095076261f62b57372caa00091889.jpg (deflated 7%)
#   adding: salesforce_images/49745938302dc06117c0f5ffc4641b51.jpg (deflated 3%)
#   adding: salesforce_images/858c7540e68f955b4b630d008037fe51.jpg (deflated 3%)
#   adding: salesforce_images/369c824b9ac0bc92fda849602b80a5b3.jpg (deflated 45%)
#   adding: salesforce_images/7ffb9c0a636198789529fbd30c13232c.jpg (deflated 53%)
#   adding: salesforce_images/d88b63a8d54b94636f6e855e695e96d3.jpg (deflated 5%)
#   adding: salesforce_images/fe0e030de79899d0eb6b8cd96fce66d0.jpg (deflated 9%)
#   adding: salesforce_images/77078fdb03829c0eef20f7f7c4fb11fb.jpg (deflated 2%)
#   adding: salesforce_images/9db7933cad330ce7c07e2aa13e0aa4c9.jpg (deflated 1%)
#   adding: salesforce_images/de0a715a5d53b07ae808bf1946d0c66b.jpg (deflated 6%)
#   adding: salesforce_images/929344637aa1c968d890516bf3aba498.jpg (deflated 0%)
#   adding: salesforce_images/b9ed3b0ef2cb1982fd6b15604bbd2969.jpg (deflated 1%)
#   adding: salesforce_images/7de9bf3b8a36a3fa197a3e8780e92ad9.jpg (deflated 15%)
#   adding: salesforce_images/18e38772cedc86aa45c45b5625979261.jpg (deflated 17%)
#   adding: salesforce_images/6f6e34f036a0ae10de13d60844ed7202.jpg (deflated 10%)
#   adding: salesforce_images/e30125edcc89807e9dd5ebdd4eb4fbe3.jpg (deflated 2%)
#   adding: salesforce_images/0ab34f6654d34b022811feeee024c05f.jpg (deflated 4%)
#   adding: salesforce_images/5ab259889dc13d1510065a0ca5658df6.jpg (deflated 47%)
#   adding: salesforce_images/d61a5b3536a9a686f59c7c7620933039.jpg (deflated 2%)
#   adding: salesforce_images/64cfadf348a33b75a074c924cf22f3fd.jpg (deflated 4%)
#   adding: salesforce_images/d10efe3dfe3561f0bc5c9d17d6ace990.jpg (deflated 5%)
#   adding: salesforce_images/dacde0593da0bf87ee47b33606b758da.jpg (deflated 3%)
#   adding: salesforce_images/93a8134fe7fd202e08b446817ee202fb.jpg (deflated 0%)
#   adding: salesforce_images/3e8f69aea4b5f957a41977787d3a9aa5.jpg (deflated 2%)
#   adding: salesforce_images/a87581ffdc7d4eec27a9687bb299c311.jpg (deflated 3%)
#   adding: salesforce_images/6fcd79f5f30f61936fbbacd903386265.jpg (deflated 0%)
#   adding: salesforce_images/ec5be475b2152769b97437755884fa95.jpg (deflated 1%)
#   adding: salesforce_images/eb38c1fc1134dd34edfce12ac1223a52.jpg (deflated 2%)
#   adding: salesforce_images/0d671af068354715db988082e1b2ea76.jpg (deflated 1%)
#   adding: salesforce_images/5eeeca4f5f7708af7d90b23e9b6bbee3.jpg (deflated 4%)
#   adding: salesforce_images/5eeb2d7cc3a56c6052385959414d36c1.jpg (deflated 1%)
#   adding: salesforce_images/9d6ebc55e1e2cc063c0254b5fe52f240.jpg (deflated 7%)
#   adding: salesforce_images/d0c8fbb0c52715e4057bfb392a27728e.jpg (deflated 4%)
#   adding: salesforce_images/12dcf5c714903c286b19ccc780b1de47.jpg (deflated 5%)
#   adding: salesforce_images/c3c3c76de8f53753d89292a421b6742a.jpg (deflated 13%)
#   adding: salesforce_images/cd1abd01c3dc33993e4e8bd1a3a1a5a7.jpg (deflated 0%)
#   adding: salesforce_images/9cb15ddf4fbbaea172a6af65240b0d9d.jpg (deflated 9%)
#   adding: salesforce_images/bb40fa5064f64140d1a1a06950ec0dad.jpg (deflated 0%)
#   adding: salesforce_images/cd17a2b02926fcd1ad0fc48c81ca319d.jpg (deflated 25%)
#   adding: salesforce_images/eb7733cefe28bfe6638d0d66e21f785c.jpg (deflated 8%)
#   adding: salesforce_images/05336acb1bdb640609dff1c54a3a918d.jpg (deflated 7%)
#   adding: salesforce_images/d34f0bee612a28dc3e6571a2a6f8e731.jpg (deflated 5%)
#   adding: salesforce_images/63b33041e6408ccd9af27c9b1b2ffa58.jpg (deflated 6%)
#   adding: salesforce_images/589ae8c0d561b362834f741b046c3e11.jpg (deflated 60%)
#   adding: salesforce_images/2ed16fc8416a5144f040c0db6bc67c32.jpg (deflated 5%)
#   adding: salesforce_images/4290112a28e05e2cb6407059f91d9422.jpg (deflated 4%)
#   adding: salesforce_images/863fca4dffc374bd29e3dd6e74f860e2.jpg (deflated 13%)
#   adding: salesforce_images/a72a1eaf1bafc42c0e9fbfeaa116b367.jpg (deflated 5%)
#   adding: salesforce_images/1f72d239c8bc73795ed99685be1523ba.jpg (deflated 5%)
#   adding: salesforce_images/32c4cb02260822d2eec7cccdc06013ff.jpg (deflated 1%)
#   adding: salesforce_images/3462005aa0986d8fc07d80d039dbc37a.jpg (deflated 0%)
#   adding: salesforce_images/6e0b08f86952c3dc10eb4bc86458b94a.jpg (deflated 7%)
#   adding: salesforce_images/f6d6de45c996d463577440a3fc2d76a5.jpg (deflated 9%)
#   adding: salesforce_images/ddadcbb4113cfed4b0020335ccd6c637.jpg (deflated 5%)
#   adding: salesforce_images/622ad640273e24973d4e8f91357818d0.jpg (deflated 16%)
#   adding: salesforce_images/82e0020a94dc096f179aad35658c3e13.jpg (deflated 22%)
#   adding: salesforce_images/d1625bc57d5420896f608ec6f2d35283.jpg (deflated 0%)
#   adding: salesforce_images/5813c5fedf6ec4aba4a9b4c7775e00ae.jpg (deflated 7%)
#   adding: salesforce_images/eb10ee8aa50e0920c0100bfd5612f7a8.jpg (deflated 1%)
#   adding: salesforce_images/46dab42a601bb6edbf0b9a7e333d0dcf.jpg (deflated 1%)
#   adding: salesforce_images/111a53a424c3bacde2ea2e9835f29fe6.jpg (deflated 5%)
#   adding: salesforce_images/db55ca4b1f2abba877eed6dad7b08740.jpg (deflated 12%)
#   adding: salesforce_images/76d06274954e92db6bcf6ca3c01ca3ce.jpg (deflated 2%)
#   adding: salesforce_images/d15cb70d25f490058d9e02295ed8d749.jpg (deflated 8%)
#   adding: salesforce_images/4f48e12f539f6e1d1cfdf10022901e47.jpg (deflated 2%)
#   adding: salesforce_images/f8a4c6c8c331369dd20271fa37b02d62.jpg (deflated 15%)
#   adding: salesforce_images/9dc2c6feb9baf620f6b89d87230bb4ac.jpg (deflated 13%)
#   adding: salesforce_images/951dfcba8395b901e8ae6817e7e373d6.jpg (deflated 2%)
#   adding: salesforce_images/baeb97cf5352980048566a7fc3c8e216.jpg (deflated 2%)
#   adding: salesforce_images/a32372e4e303be8f8eb1739d0b470cc7.jpg (deflated 5%)
#   adding: salesforce_images/16cb484bc3dd06bafc4c6ccff62a3b02.jpg (deflated 5%)
#   adding: salesforce_images/475b96e261530153d1c4430e44bbfd30.jpg (deflated 7%)
#   adding: salesforce_images/404ec0ef197a26e39540086a3df9aa39.jpg (deflated 1%)
#   adding: salesforce_images/e0eacb8f6d52aa060bd445c9351dedc4.jpg (deflated 1%)
#   adding: salesforce_images/9a28dd4fac76b1e2ec90cdc20cc06d1c.jpg (deflated 4%)
#   adding: salesforce_images/90a20ab659f6e70ce27e119c278d353e.jpg (deflated 8%)
#   adding: salesforce_images/050aba6d61ec39b5dffd9f958e1b296f.jpg (deflated 1%)
#   adding: salesforce_images/e4acce673cf313cef511fc6d1bd9246f.jpg (deflated 10%)
#   adding: salesforce_images/1580010df6004e4683046cb911e84bcd.jpg (deflated 4%)
#   adding: salesforce_images/fef051cdf6a13326cbecd739b82180b5.jpg (deflated 0%)
#   adding: salesforce_images/a192bd563d242f02d5f079c0187b1ac7.jpg (deflated 1%)
#   adding: salesforce_images/b144d574afde99946e67e27f2fa81cce.jpg (deflated 0%)
#   adding: salesforce_images/bd675bc613c05f016f06ed393f3d23a5.jpg (deflated 1%)
#   adding: salesforce_images/9933b91930bee3578cda839edfa88ad2.jpg (deflated 1%)
#   adding: salesforce_images/1053a8dd893cfd9d236861bae1206336.jpg (deflated 5%)
#   adding: salesforce_images/d07b938ab36da2d3ca86669fad291075.jpg (deflated 7%)
#   adding: salesforce_images/1a1e3ce89ad3cc19ada48170c606c80f.jpg (deflated 4%)
#   adding: salesforce_images/be79ac5b51400777391124eed8f109df.jpg (deflated 2%)
#   adding: salesforce_images/1f318bd220d5e3b6e5f4c88c3a8e6150.jpg (deflated 1%)
#   adding: salesforce_images/00ec05d5b951ec51d2165261aea27a32.jpg (deflated 0%)
#   adding: salesforce_images/48e5398029d5df50bf719930ce3f048b.jpg (deflated 18%)
#   adding: salesforce_images/e3f0e6308690ea6c7757a784056aea96.jpg (deflated 7%)
#   adding: salesforce_images/0a70dd932d302c899fa33f62d5543ac8.jpg (deflated 1%)
#   adding: salesforce_images/53dcd243e3440d4006b200a43fb8a087.jpg (deflated 19%)
#   adding: salesforce_images/000a9e3de163e875bb917f87efd4e8fb.jpg (deflated 18%)
#   adding: salesforce_images/b172617430c37165cda780628d95af5d.jpg (deflated 1%)
#   adding: salesforce_images/b535b4c6db02de5cf4085673d0e043b8.jpg (deflated 3%)
#   adding: salesforce_images/1c5f24437a2c870f446f463c619809e8.jpg (deflated 4%)
#   adding: salesforce_images/8dd53ba53e5ed727ef86ab1735797c13.jpg (deflated 0%)
#   adding: salesforce_images/c9ba7020aae08ad079d58ceabc44a64f.jpg (deflated 2%)
#   adding: salesforce_images/c789d102fb1c1e2f7fb688ba04f770f0.jpg (deflated 1%)
#   adding: salesforce_images/7826bf5cdd0d58145248eb6f50773140.jpg (deflated 27%)
#   adding: salesforce_images/08c1b28247f17946e94777a60a0008f1.jpg (deflated 1%)
#   adding: salesforce_images/d1f5ba869a4e9ea07c8c61f12a59ffd2.jpg (deflated 8%)
#   adding: salesforce_images/5601b7f19c74978c8c260b72db70c96e.jpg (deflated 15%)
#   adding: salesforce_images/5ba8e839c66e3c8d65fac3627007b90c.jpg (deflated 3%)
#   adding: salesforce_images/efa6112fda08101226f1ca7174bfa15b.jpg (deflated 3%)
#   adding: salesforce_images/44b0913e1ac84ec0d42582c661144124.jpg (deflated 7%)
#   adding: salesforce_images/de7a0f1133f26c8c119ec4367132f678.jpg (deflated 4%)
#   adding: salesforce_images/37d62036322b0f47098b05d54615eabc.jpg (deflated 9%)
#   adding: salesforce_images/026c840c2296dec9beea305432d33833.jpg (deflated 34%)
#   adding: salesforce_images/7a849e69077f8a5246e0f01b0208ed8a.jpg (deflated 4%)
#   adding: salesforce_images/736fccc0b93a7e644626da7bb50af9f2.jpg (deflated 0%)
#   adding: salesforce_images/0ac14d44532ac89c323d41230e6778b3.jpg (deflated 14%)
#   adding: salesforce_images/4dd6ad98622857bb7004f1259d9813ab.jpg (deflated 3%)
#   adding: salesforce_images/b23b4499d4d65be3e8a9cea45ed3dc4a.jpg (deflated 2%)
#   adding: salesforce_images/ca2fc15b355cfbdc37718dd83a115a4b.jpg (deflated 0%)
#   adding: salesforce_images/c496798601348c6327b88a664b51568d.jpg (deflated 4%)
#   adding: salesforce_images/aa68ea7c7d52344a4bec7d8314420c83.jpg (deflated 3%)
#   adding: salesforce_images/8cf521908a886d089ac68c65f12b30f7.jpg (deflated 11%)
#   adding: salesforce_images/9e6954ce4b41e962f96d26aded06dfe5.jpg (deflated 0%)
#   adding: salesforce_images/43a1e6ba3c0101a66ab1b51282018700.jpg (deflated 10%)

# %% [markdown]
# ### 4.4. Generate OCR QA Pairs for Reasoning Pipeline
#
# Now we'll use the OCR Data Bridge to convert our Salesforce OCR data into the format expected by the multimodal QRA reasoning pipeline. This is the critical integration step that connects OCR data processing with reasoning trace generation.

# %%
os.getcwd()
# Out:
# '/kaggle/working/moremi_reasoning'

# %%
# get all file names from the `salesforce_test` directory
import os
import sys

# sys.path.append("../src")
from src.ocr_data_bridge import OCRDataBridge

# Initialize the bridge
bridge = OCRDataBridge()

IMAGE_DIR = os.path.join(os.getcwd(), "salesforce_images")
SAMPLE_IMAGE_LIST_FILE = os.path.join(os.getcwd(), "salesforce_ocr/all_image_files.txt")


with open(SAMPLE_IMAGE_LIST_FILE, "r") as f:
    all_image_files = [line.strip() for line in f.readlines() if line.strip()]

# Print the number of files found
files_found = len(all_image_files)
print(f"Found {files_found} files in the directory: {IMAGE_DIR}")
sample_size = files_found


def get_ocr_text_for_qna(
    sample_row, desired_granularity=0, prefer_no_raw_datacomp=True
):
    if sample_row is None:
        return None

    captions_str = sample_row.get("captions")
    if not captions_str:
        return None

    try:
        captions_list = json.loads(captions_str)
        # Try to find the exact granularity, optionally filtering by include_datacomp_raw_cap
        for cap_obj in captions_list:
            if cap_obj.get("granularity") == desired_granularity:
                if (
                    prefer_no_raw_datacomp
                    and cap_obj.get("include_datacomp_raw_cap") == True
                ):
                    continue
                return cap_obj.get("text")

        # Fallback: if exact granularity with preference not found, try without preference
        if prefer_no_raw_datacomp:
            for cap_obj in captions_list:
                if cap_obj.get("granularity") == desired_granularity:
                    return cap_obj.get("text")

        # Fallback: if desired_granularity not found at all, try to get any text from granularity 0 or 5
        for cap_obj in captions_list:
            if cap_obj.get("granularity") == 0:
                if (
                    prefer_no_raw_datacomp
                    and cap_obj.get("include_datacomp_raw_cap") == True
                ):
                    continue
                return cap_obj.get("text")
        for cap_obj in captions_list:
            if cap_obj.get("granularity") == 5:
                if (
                    prefer_no_raw_datacomp
                    and cap_obj.get("include_datacomp_raw_cap") == True
                ):
                    continue
                # Clean the XML-like tags from granularity 5 for a cleaner answer
                text_g5 = cap_obj.get("text")
                if text_g5:
                    return re.sub(
                        r"<ocr>([^<]+)</ocr><bbox>[^<]+</bbox>", r"\1", text_g5
                    ).strip()
                return None  # Should not happen if text_g5 exists

        # Final fallback: return the first caption's text if any
        if captions_list:
            return captions_list[0].get("text")

    except json.JSONDecodeError:
        return None
    return None


if df is not None and not df.empty:
    sample_for_qna = df.iloc[0]

    # --- Configuration for Q&A Generation ---
    # You can change this to experiment with different OCR outputs
    # Granularity 0: Basic text extraction.
    # Granularity 5: Text with OCR tags and bounding boxes (will be cleaned by get_ocr_text_for_qna).
    CHOSEN_GRANULARITY_FOR_ANSWER = 7
    # --- End Configuration ---

    ground_truth_ocr_text = get_ocr_text_for_qna(
        sample_for_qna, CHOSEN_GRANULARITY_FOR_ANSWER
    )

    if ground_truth_ocr_text:
        question = "What is all the text visible in this image?"
        image_uid = sample_for_qna.get("uid")
        image_url_for_qna = sample_for_qna.get("url")

        print(f"--- Generated Q&A for Image UID: {image_uid} ---")
        print(f"Image URL: {image_url_for_qna}")
        print(f"Question: {question}")
        print(
            f"Ground-Truth Answer (from Granularity {CHOSEN_GRANULARITY_FOR_ANSWER}, cleaned):\n{ground_truth_ocr_text}"
        )

        # This is the data structure one item of your preprocessed list would look like for multimodal_QRA_pair.py
        # (assuming multimodal_QRA_pair.py's main data loading is bypassed or adapted)
        prepared_data_item = {
            "process_id": image_uid,  # Or some other unique ID
            "Open-ended Verifiable Question": question,
            "Ground-True Answer": ground_truth_ocr_text,
            "img_urls": [
                image_url_for_qna
            ],  # multimodal_QRA_pair.py expects a list of URLs
        }
        print("\nPrepared data item structure for the reasoning script:")
        print(json.dumps(prepared_data_item, indent=2))
    else:
        print(
            f"Could not extract suitable OCR text for Q&A from sample row (UID: {sample_for_qna.get('uid')})."
        )
else:
    print("DataFrame not loaded or empty, skipping Q&A formulation.")

# Make sure re is imported if not already
import re
import json
import random

# Since we have the file names in all_image_files, let's randomly sample one
random_file = random.choice(all_image_files) if all_image_files else None

if random_file:
    # Extract UID from filename (assuming filename contains the UID)
    uid = random_file.split(".")[0]  # Remove extension

    print(f"Selected random file: {random_file}")
    print(f"Extracted UID: {uid}")

    # Create a mock sample row with minimal required fields
    sample_row = {
        "uid": uid,
        "url": f"{IMAGE_DIR}/{random_file}",
        "captions": json.dumps(
            [
                {
                    "granularity": 0,
                    "text": f"Sample OCR text for {uid}",
                    "include_datacomp_raw_cap": False,
                },
                {
                    "granularity": 5,
                    "text": f"<ocr>Sample OCR text for {uid}</ocr><bbox>0,0,100,100</bbox>",
                    "include_datacomp_raw_cap": False,
                },
            ]
        ),
    }

    # Use the existing function to get OCR text
    ocr_text = get_ocr_text_for_qna(sample_row, CHOSEN_GRANULARITY_FOR_ANSWER)

    # Create sample Q&A
    question = "What is all the text visible in this image?"
    prepared_data_item = {
        "process_id": uid,
        "Open-ended Verifiable Question": question,
        "Ground-True Answer": ocr_text,
        "img_urls": [sample_row["url"]],
    }

    print("\nGenerated sample Q&A:")
    print(json.dumps(prepared_data_item, indent=2))
else:
    print("No files found to sample.")

# Create QA pairs from our Salesforce data
print("=== Generating OCR QA Pairs ===")
print(f"Working with {len(df)} rows of Salesforce OCR data")
print(f"Image directory: {IMAGE_DIR}")

# Generate QA pairs using different granularities
for granularity in [0, 5]:  # Test both granularities
    print(f"\n--- Processing Granularity {granularity} ---")

    qa_pairs = bridge.create_ocr_qa_pairs(
        salesforce_df=df,
        image_dir=IMAGE_DIR,
        num_samples=50,  # Start with small sample for testing
        granularity=granularity,
        seed=42,
    )

    print(f"Generated {len(qa_pairs)} QA pairs")

    # Validate the QA pairs
    validation = bridge.validate_qa_pairs(qa_pairs)
    print(f"Validation Results:")
    print(f"  Total pairs: {validation['total_pairs']}")
    print(f"  Valid pairs: {validation['valid_pairs']}")
    print(f"  Issues found: {len(validation['issues'])}")

    if validation["issues"]:
        print("\nFirst few issues:")
        for issue in validation["issues"][:3]:
            print(f"  - Pair {issue['pair_index']}: {issue['issues']}")

    # Save for reasoning pipeline
    output_file = f"ocr_qa_pairs_granularity_{granularity}.json"
    bridge.save_for_reasoning_pipeline(qa_pairs, output_file)

    # Show sample QA pair
    if qa_pairs:
        print(f"\nSample QA Pair (Granularity {granularity}):")
        sample = qa_pairs[0]
        print(f"  Question: {sample['Open-ended Verifiable Question']}")
        print(
            f"  Answer: {sample['Ground-True Answer'][:200]}{'...' if len(sample['Ground-True Answer']) > 200 else ''}"
        )
        print(f"  Image URLs: {sample['img_urls']}")
        print(f"  Process ID: {sample['process_id']}")

print("\n=== OCR QA Pair Generation Complete ===")
print("Files generated:")
print("- ocr_qa_pairs_granularity_0.json")
print("- ocr_qa_pairs_granularity_5.json")
print("\nThese files are now ready for the reasoning pipeline!")
# Out:
# Found 11 files in the directory: /kaggle/working/moremi_reasoning/salesforce_images
# --- Generated Q&A for Image UID: 73142d356bceb4a9b16e41f7a78807e9 ---
# Image URL: https://d2840bd96689bd871bd1-41a6b1bb2f8a7c769906f5cde19335fe.ssl.cf1.rackcdn.com/thumbnails/3HGGK5H46LM702372/0d58289257f95d4db9562b8e86124ab5.jpg
# Question: What is all the text visible in this image?
# Ground-Truth Answer (from Granularity 0, cleaned):
# The image contains the text "BOCH", the text "20 Year / 200,000 Mile Warranty"
#
# Prepared data item structure for the reasoning script:
# {
#   "process_id": "73142d356bceb4a9b16e41f7a78807e9",
#   "Open-ended Verifiable Question": "What is all the text visible in this image?",
#   "Ground-True Answer": "The image contains the text \"BOCH\", the text \"20 Year / 200,000 Mile Warranty\"",
#   "img_urls": [
#     "https://d2840bd96689bd871bd1-41a6b1bb2f8a7c769906f5cde19335fe.ssl.cf1.rackcdn.com/thumbnails/3HGGK5H46LM702372/0d58289257f95d4db9562b8e86124ab5.jpg"
#   ]
# }
# Selected random file: 98e83726f08aaa4420a3c819ea60f3ca.jpg
# Extracted UID: 98e83726f08aaa4420a3c819ea60f3ca
#
# Generated sample Q&A:
# {
#   "process_id": "98e83726f08aaa4420a3c819ea60f3ca",
#   "Open-ended Verifiable Question": "What is all the text visible in this image?",
#   "Ground-True Answer": "Sample OCR text for 98e83726f08aaa4420a3c819ea60f3ca",
#   "img_urls": [
#     "/kaggle/working/moremi_reasoning/salesforce_images/98e83726f08aaa4420a3c819ea60f3ca.jpg"
#   ]
# }
# === Generating OCR QA Pairs ===
# Working with 7000 rows of Salesforce OCR data
# Image directory: /kaggle/working/moremi_reasoning/salesforce_images
#
# --- Processing Granularity 0 ---
# Generated 50 QA pairs
# Validation Results:
#   Total pairs: 50
#   Valid pairs: 50
#   Issues found: 0
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_74/446895364.py in <cell line: 0>()
#     212     # Save for reasoning pipeline
#     213     output_file = f"ocr_qa_pairs_granularity_{granularity}.json"
# --> 214     bridge.save_for_reasoning_pipeline(qa_pairs, output_file)
#     215
#     216     # Show sample QA pair
#
# /kaggle/working/moremi_reasoning/src/ocr_data_bridge.py in save_for_reasoning_pipeline(self, qa_pairs, output_path)
#     150
#     151         # Ensure output directory exists
# --> 152         os.makedirs(os.path.dirname(output_path), exist_ok=True)
#     153
#     154         with open(output_path, 'w', encoding='utf-8') as f:
#
# /usr/lib/python3.11/os.py in makedirs(name, mode, exist_ok)
#
# FileNotFoundError: [Errno 2] No such file or directory: ''

# %%
# Test images from SAMPLE_IMAGE_LIST_FILE
import os
import json
from PIL import Image
import requests
from io import BytesIO
from src.ocr_question_generator import OCRQuestionGenerator

ocr_generator = OCRQuestionGenerator()
# Read image files from the list
print(f"Reading image files from: {SAMPLE_IMAGE_LIST_FILE}")
print(f"Image directory: {IMAGE_DIR}")

# Test a few images from the list
test_image_files = all_image_files[:5]  # Test first 5 images
print(f"\nTesting {len(test_image_files)} images from the list:")

for i, image_file in enumerate(test_image_files, 1):
    image_path = os.path.join(IMAGE_DIR, image_file)
    uid = image_file.split(".")[0]  # Extract UID from filename

    print(f"\n{i}. Testing image: {image_file}")
    print(f"   UID: {uid}")
    print(f"   Path: {image_path}")

    # Check if image exists locally
    if os.path.exists(image_path):
        try:
            # Try to open and verify the image
            with Image.open(image_path) as img:
                print(f"   ✓ Valid image - Size: {img.size}, Mode: {img.mode}")

                # Find corresponding data in DataFrame
                matching_row = df[df["uid"] == uid]
                if not matching_row.empty:
                    row_data = matching_row.iloc[0]
                    print(f"   ✓ Found matching data in DataFrame")
                    print(f"   URL: {row_data.get('url', 'N/A')}")

                    # Extract OCR text for testing
                    captions_str = row_data.get("captions")
                    if captions_str:
                        try:
                            captions_list = json.loads(captions_str)
                            for cap_obj in captions_list:
                                if cap_obj.get("granularity") == 0:
                                    ocr_text = cap_obj.get("text", "")
                                    print(f"   OCR Text (preview): {ocr_text[:100]}...")
                                    break
                        except json.JSONDecodeError:
                            print("   ⚠️ Could not parse captions JSON")
                else:
                    print(f"   ⚠️ No matching data found in DataFrame for UID: {uid}")

        except Exception as e:
            print(f"   ✗ Error opening image: {e}")
    else:
        print(f"   ✗ Image file not found at: {image_path}")

# Generate OCR questions for the test images
print(f"\n=== Generating OCR Questions for Test Images ===")
test_samples = []

for image_file in test_image_files:
    image_path = os.path.join(IMAGE_DIR, image_file)
    uid = image_file.split(".")[0]

    if os.path.exists(image_path):
        # Find matching row in DataFrame
        matching_row = df[df["uid"] == uid]
        if not matching_row.empty:
            row_data = matching_row.iloc[0].to_dict()

            # Generate diverse questions for this image
            diverse_questions = ocr_generator.generate_diverse_questions(3)

            for question in diverse_questions:
                # Extract OCR text as ground truth
                ground_truth = get_ocr_text_for_qna(row_data, 0)  # Use granularity 0

                if ground_truth:
                    test_sample = {
                        "process_id": uid,
                        "img_urls": [image_path],  # Use local path
                        "question": question,
                        "ground-truth": ground_truth,
                        "metadata": {
                            "difficulty": ocr_generator.assess_difficulty(question),
                            "question_type": ocr_generator.categorize_question(
                                question
                            ),
                            "image_file": image_file,
                        },
                    }
                    test_samples.append(test_sample)

print(f"Generated {len(test_samples)} test samples from image list")

# Save test samples for reasoning pipeline
if test_samples:
    test_output_file = "ocr_test_samples_from_list.json"
    with open(test_output_file, "w", encoding="utf-8") as f:
        json.dump(test_samples, f, ensure_ascii=False, indent=2)

    print(f"\nSaved test samples to: {test_output_file}")

    # Display sample
    print("\nSample test data:")
    sample = test_samples[0]
    print(f"  Image: {sample['metadata']['image_file']}")
    print(f"  Question: {sample['Open-ended Verifiable Question']}")
    print(f"  Answer: {sample['Ground-True Answer'][:150]}...")
    print(f"  Difficulty: {sample['metadata']['difficulty']}")
    print(f"  Type: {sample['metadata']['question_type']}")
else:
    print("No valid test samples generated")
# Out:
# Reading image files from: /kaggle/working/moremi_reasoning/salesforce_ocr/all_image_files.txt
# Image directory: /kaggle/working/moremi_reasoning/salesforce_images
#
# Testing 5 images from the list:
#
# 1. Testing image: 6f87885362ba58d8ebee51378da401a7.jpg
#    UID: 6f87885362ba58d8ebee51378da401a7
#    Path: /kaggle/working/moremi_reasoning/salesforce_images/6f87885362ba58d8ebee51378da401a7.jpg
#    ✓ Valid image - Size: (128, 159), Mode: RGB
#    ✓ Found matching data in DataFrame
#    URL: https://books.google.ca/books/content?id=NhAEAAAAMBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&imgtk=AFLRE737XKBhH1OfMiawD5sbc38i4ikRDgU9pBJQZjjAH0yekR8XlABkFusCEqQKpw0lkHB9TWF_rjRIEle6M1NsDKffy4VXb3_7zB9MX5VDKlzfif8pmx4SgJkXy74BbpOUzJPbQeUS
#    OCR Text (preview): The image contains the text "Billboard", the text "kylie minogue"...
#
# 2. Testing image: 72732f1e5509203199c0757a82c3c321.jpg
#    UID: 72732f1e5509203199c0757a82c3c321
#    Path: /kaggle/working/moremi_reasoning/salesforce_images/72732f1e5509203199c0757a82c3c321.jpg
#    ✓ Valid image - Size: (236, 347), Mode: RGB
#    ✓ Found matching data in DataFrame
#    URL: https://dspncdn.com/a1/media/236x/39/68/ed/3968eded782c33ddc1402c0c58642126.jpg
#    OCR Text (preview): The image contains the text "IMAGINATION:", the text "MAPSOF THE", the text "AS CARTOGRAPHER", the t...
#
# 3. Testing image: 646d9028775dc62287bf6d3c5b15d98c.jpg
#    UID: 646d9028775dc62287bf6d3c5b15d98c
#    Path: /kaggle/working/moremi_reasoning/salesforce_images/646d9028775dc62287bf6d3c5b15d98c.jpg
#    ✓ Valid image - Size: (696, 385), Mode: RGB
#    ✓ Found matching data in DataFrame
#    URL: https://seniorslifestylemag.com/wp-content/uploads/2019/09/breast-cancer-696x385.jpg
#    OCR Text (preview): The image contains the text "Breast Cancer Awareness Month", the text "OCTOBER"...
#
# 4. Testing image: ab8aa466524a67eededf62f4d07ffff1.jpg
#    UID: ab8aa466524a67eededf62f4d07ffff1
#    Path: /kaggle/working/moremi_reasoning/salesforce_images/ab8aa466524a67eededf62f4d07ffff1.jpg
#    ✓ Valid image - Size: (238, 212), Mode: RGB
#    ✓ Found matching data in DataFrame
#    URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSC6hv9krbvbAYcXds6IFFmXCJd8gA8imgD-Ynhfwoyg0uQo23B
#    OCR Text (preview): The image contains the text "Bedtirne", the text "Roasted"...
#
# 5. Testing image: a95178e7a3c21aca2e9f6431be30db13.jpg
#    UID: a95178e7a3c21aca2e9f6431be30db13
#    Path: /kaggle/working/moremi_reasoning/salesforce_images/a95178e7a3c21aca2e9f6431be30db13.jpg
#    ✓ Valid image - Size: (320, 320), Mode: RGB
#    ✓ Found matching data in DataFrame
#    URL: http://media-cache-ec0.pinimg.com/736x/1a/b5/d1/1ab5d1cf0ea867cca7051a60dec1b8d6.jpg
#    OCR Text (preview): The image contains the text "For God so loVed the world", the text "that He gAve", the text "His onL...
#
# === Generating OCR Questions for Test Images ===
# Generated 15 test samples from image list
#
# Saved test samples to: ocr_test_samples_from_list.json
#
# Sample test data:
#   Image: 6f87885362ba58d8ebee51378da401a7.jpg
#   Question: What text can you see in this image?
#   Answer: The image contains the text "Billboard", the text "kylie minogue"...
#   Difficulty: basic
#   Type: challenging_scenarios

# %%
# !rm -rf salesforce_images.zip

# %%
os.listdir()
# !rm -rf salesforce_images.zip
# Out:
# ['section_5_enhancement_summary.md',
#  'ocr_test_samples_from_list.json',
#  'ocr_test_data.json',
#  'all_image_files.txt',
#  'state.db',
#  'salesforce_data',
#  'output.json',
#  'logs',
#  'src',
#  'salesforce_images',
#  'salesforce_ocr',
#  '.gitignore',
#  '.git',
#  'README.md']

# %%
# show number of files in `salesforce_images` directory
import os

IMAGE_DIR = os.path.join(os.getcwd(), "salesforce_images")
if not os.path.exists(IMAGE_DIR):
    print(f"ERROR: Image directory '{IMAGE_DIR}' does not exist.")
else:
    print(f"Image directory exists: {IMAGE_DIR}")

image_files = os.listdir(IMAGE_DIR)
print(f"Number of image files in '{IMAGE_DIR}': {len(image_files)}")
# Out:
# Image directory exists: /kaggle/working/moremi_reasoning/salesforce_images
# Number of image files in '/kaggle/working/moremi_reasoning/salesforce_images': 12081

# %% [markdown]
# ## 5. Running the OCR Reasoning Pipeline
#
# Now that we have properly formatted QA pairs, we can run the multimodal QRA reasoning pipeline with our improved OCR-specific prompts.

# %%
# Enhanced OCR Reasoning Pipeline Execution
import os
import sys
import json
import yaml
import subprocess
import time
import traceback
from pathlib import Path
from datetime import datetime

# 1. Prepare the environment and configurations
print("=== Setting up Enhanced OCR Reasoning Pipeline ===")

# Get the current working directory and set up paths
current_dir = Path.cwd()
src_dir = current_dir / "src"
config_dir = src_dir / "config"

print(f"Current directory: {current_dir}")
print(f"Source directory: {src_dir}")
print(f"Config directory: {config_dir}")

# Create logs directory for tracking
logs_dir = current_dir / "logs"
logs_dir.mkdir(exist_ok=True)


# 2. Validate environment setup
def validate_environment():
    """Validate that all required components are available"""
    issues = []

    # Check API key
    api_key = API_KEY
    if not api_key:
        issues.append("API_KEY environment variable not set")
    elif len(api_key) < 20:
        issues.append("API_KEY appears to be too short")

    # Check configuration files
    config_file = config_dir / "reasoning_config.yaml"
    prompts_file = config_dir / "reasoning_prompts.yaml"

    if not config_file.exists():
        issues.append(f"Configuration file missing: {config_file}")
    if not prompts_file.exists():
        issues.append(f"Prompts file missing: {prompts_file}")

    # Check QA pairs file
    qa_pairs_file = current_dir / "ocr_test_samples_from_list.json"
    if not qa_pairs_file.exists():
        issues.append(f"QA pairs file missing: {qa_pairs_file}")

    # Check source files
    pipeline_script = src_dir / "multimodal_QRA_pair.py"
    if not pipeline_script.exists():
        issues.append(f"Pipeline script missing: {pipeline_script}")

    return issues


# 3. Enhanced configuration setup
def setup_pipeline_config():
    """Set up optimized configuration for OCR reasoning"""
    config_file = config_dir / "reasoning_config.yaml"

    if not config_file.exists():
        print("⚠️ Configuration file not found!")
        return False

    with open(config_file, "r") as f:
        reasoning_config = yaml.safe_load(f)

    # Backup original config
    backup_file = config_file.with_suffix(".yaml.backup")
    with open(backup_file, "w") as f:
        yaml.dump(reasoning_config, f, default_flow_style=False)

    # Update configuration for OCR processing
    updates = {
        "data_path": str(current_dir / "ocr_test_samples_from_list.json"),
        "image_dir": str(current_dir / "salesforce_images"),
        "limit_num": 10,  # Start with manageable size
        "max_search_attempts": 3,
        "efficient_search": True,
        "num_process": 1,
        "batch_size": 3,
        "save_progress": True,
        "verbose": True,
        "model_name": "google/gemini-2.0-flash-001",
    }

    for key, value in updates.items():
        reasoning_config[key] = value

    # Save updated configuration
    with open(config_file, "w") as f:
        yaml.dump(reasoning_config, f, default_flow_style=False)

    print("✓ Updated reasoning configuration:")
    for key, value in updates.items():
        print(f"  {key}: {value}")

    return True


# 4. Run validation
print("\n=== Environment Validation ===")
validation_issues = validate_environment()

if validation_issues:
    print("❌ Environment validation failed:")
    for issue in validation_issues:
        print(f"  - {issue}")
    print("\nPlease fix these issues before proceeding.")
else:
    print("✅ Environment validation passed!")

# 5. Set up configuration
if not validation_issues:
    config_success = setup_pipeline_config()
    if config_success:
        print("✓ Configuration setup complete")


# 6. Enhanced pipeline execution with monitoring
def run_ocr_reasoning_pipeline():
    """Run the OCR reasoning pipeline with enhanced monitoring"""

    if validation_issues:
        print("❌ Cannot run pipeline due to validation issues")
        return False

    print("\n🚀 Starting Enhanced OCR Reasoning Pipeline...")

    # Set up logging
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    log_file = logs_dir / f"ocr_reasoning_pipeline_{timestamp}.log"

    try:
        # Add src to Python path
        sys.path.insert(0, str(src_dir))

        # Change to src directory
        original_dir = os.getcwd()
        os.chdir(str(src_dir))

        # Start timing
        start_time = time.time()

        # Import and run the pipeline
        from multimodal_QRA_pair import main as run_reasoning_pipeline

        print("✓ Pipeline module imported successfully")
        print("📊 Processing OCR questions with Chain of Thought reasoning...")
        print(f"📝 Logs will be saved to: {log_file}")

        # Capture output for logging
        import io
        import contextlib

        f = io.StringIO()
        with contextlib.redirect_stdout(f):
            run_reasoning_pipeline()

        output = f.getvalue()

        # Save log
        with open(log_file, "w", encoding="utf-8") as log:
            log.write(f"OCR Reasoning Pipeline Log - {timestamp}\n")
            log.write("=" * 50 + "\n\n")
            log.write(output)

        # Calculate execution time
        execution_time = time.time() - start_time

        print(f"\n✅ Pipeline completed successfully in {execution_time:.2f} seconds!")
        print(f"📊 Check the output files for reasoning results")

        return True

    except ImportError as e:
        error_msg = f"Failed to import pipeline module: {str(e)}"
        print(f"❌ {error_msg}")
        with open(log_file, "w") as log:
            log.write(f"ERROR: {error_msg}\n{traceback.format_exc()}")
        return False

    except Exception as e:
        error_msg = f"Pipeline execution failed: {str(e)}"
        print(f"❌ {error_msg}")
        print(f"💡 Check log file for details: {log_file}")
        with open(log_file, "w") as log:
            log.write(f"ERROR: {error_msg}\n{traceback.format_exc()}")
        return False

    finally:
        # Return to original directory
        os.chdir(original_dir)


# 7. Execute the pipeline
if not validation_issues:
    pipeline_success = run_ocr_reasoning_pipeline()

    if pipeline_success:
        # 8. Quick results check
        print("\n=== Quick Results Check ===")

        output_files = []
        for directory in [current_dir, src_dir]:
            output_files.extend(list(directory.glob("*ocr_qa_pairs*CoT_search*.json")))
            output_files.extend(list(directory.glob("simplified_*ocr_qa_pairs*.json")))

        if output_files:
            print(f"✓ Found {len(output_files)} output files:")
            for file in output_files[:3]:  # Show first 3
                try:
                    with open(file, "r", encoding="utf-8") as f:
                        data = json.load(f)
                    if isinstance(data, list) and data:
                        successful = sum(
                            1
                            for item in data
                            if item.get("found_correct_answer", False)
                        )
                        print(
                            f"  📁 {file.name}: {len(data)} samples, {successful} successful"
                        )
                except:
                    print(f"  📁 {file.name}: Could not analyze")
        else:
            print("⚠️ No output files found - check logs for issues")

else:
    print("\n💡 To proceed manually:")
    print("1. Fix the validation issues listed above")
    print("2. Set API_KEY: export API_KEY='sk-or-v1-your-key'")
    print("3. Run: cd src && python multimodal_QRA_pair.py")

print("\n=== Pipeline Execution Summary ===")
if not validation_issues and "pipeline_success" in locals() and pipeline_success:
    print("🎉 OCR Reasoning Pipeline completed successfully!")
    print("📈 Proceed to quality assessment in the next cell")
elif validation_issues:
    print("🔧 Environment setup needed - address validation issues first")
else:
    print("⚠️ Pipeline execution encountered issues - check logs for details")

print("\n📋 Next Steps:")
print("1. Review quality assessment results")
print("2. Analyze reasoning strategies and success patterns")
print("3. Refine prompts based on performance")
print("4. Scale up to larger datasets if results are satisfactory")
# Out:
# === Setting up Enhanced OCR Reasoning Pipeline ===
# Current directory: /kaggle/working/moremi_reasoning
# Source directory: /kaggle/working/moremi_reasoning/src
# Config directory: /kaggle/working/moremi_reasoning/src/config
#
# === Environment Validation ===
# ✅ Environment validation passed!
# ✓ Updated reasoning configuration:
#   data_path: /kaggle/working/moremi_reasoning/ocr_test_samples_from_list.json
#   image_dir: /kaggle/working/moremi_reasoning/salesforce_images
#   limit_num: 10
#   max_search_attempts: 3
#   efficient_search: True
#   num_process: 1
#   batch_size: 3
#   save_progress: True
#   verbose: True
#   model_name: google/gemini-2.0-flash-001
# ✓ Configuration setup complete
#
# 🚀 Starting Enhanced OCR Reasoning Pipeline...
# Processing samples:   0%|          | 0/10 [00:00<?, ?sample/s]
# ✓ Pipeline module imported successfully
# 📊 Processing OCR questions with Chain of Thought reasoning...
# 📝 Logs will be saved to: /kaggle/working/moremi_reasoning/logs/ocr_reasoning_pipeline_20250528_170654.log
# Processing samples: 100%|██████████| 10/10 [01:21<00:00,  8.16s/sample]
# ✅ Pipeline completed successfully in 84.44 seconds!
# 📊 Check the output files for reasoning results
#
# === Quick Results Check ===
# ⚠️ No output files found - check logs for issues
#
# === Pipeline Execution Summary ===
# 🎉 OCR Reasoning Pipeline completed successfully!
# 📈 Proceed to quality assessment in the next cell
#
# 📋 Next Steps:
# 1. Review quality assessment results
# 2. Analyze reasoning strategies and success patterns
# 3. Refine prompts based on performance
# 4. Scale up to larger datasets if results are satisfactory

# %%
# Comprehensive OCR Reasoning Results Analysis
import json
import os
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from collections import defaultdict, Counter
import seaborn as sns

print("=== Comprehensive OCR Reasoning Analysis ===")

# Look for output files
current_dir = Path.cwd()
src_dir = current_dir / "src"

# Enhanced search for output files
output_files = []
search_patterns = [
    "*ocr_qa_pairs*CoT_search*.json",
    "simplified_*ocr_qa_pairs*.json",
    "reasoning_data_new/**/*.json",
    "*CoT_search*.json"
]

for directory in [current_dir, src_dir]:
    for pattern in search_patterns:
        output_files.extend(list(directory.glob(pattern)))

# Remove duplicates and sort by modification time
output_files = list(set(output_files))
output_files.sort(key=lambda x: x.stat().st_mtime, reverse=True)

def analyze_ocr_reasoning_performance(file_path):
    """Comprehensive analysis of OCR reasoning performance"""
    
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
        
        if not isinstance(data, list) or not data:
            return None
        
        print(f"\n{'='*60}")
        print(f"Analyzing: {file_path.name}")
        print(f"{'='*60}")
        
        # Basic metrics
        total_samples = len(data)
        successful = [item for item in data if item.get('found_correct_answer', False)]
        failed = [item for item in data if not item.get('found_correct_answer', False)]
        
        success_rate = len(successful) / total_samples * 100
        
        print(f"📈 Overall Performance:")
        print(f"  Total samples: {total_samples}")
        print(f"  Successful: {len(successful)} ({success_rate:.1f}%)")
        print(f"  Failed: {len(failed)} ({100-success_rate:.1f}%)")
        
        # Reasoning attempt analysis
        attempt_counts = []
        strategy_usage = defaultdict(int)
        
        for item in data:
            attempts = item.get('reasoning_attempts', [])
            attempt_counts.append(len(attempts))
            
            for strategy in attempts:
                strategy_usage[strategy] += 1
        
        if attempt_counts:
            avg_attempts = sum(attempt_counts) / len(attempt_counts)
            print(f"\n🤔 Reasoning Analysis:")
            print(f"  Average attempts per question: {avg_attempts:.1f}")
            print(f"  Max attempts: {max(attempt_counts)}")
            print(f"  Min attempts: {min(attempt_counts)}")
            
            if strategy_usage:
                print(f"\n🛠️ Strategy Usage:")
                for strategy, count in sorted(strategy_usage.items(), key=lambda x: x[1], reverse=True):
                    percentage = count / sum(strategy_usage.values()) * 100
                    print(f"  {strategy}: {count} times ({percentage:.1f}%)")
        
        # Text length analysis
        gt_lengths = []
        response_lengths = []
        question_lengths = []
        
        for item in data:
            gt_text = item.get('Ground-True Answer', '')
            response_text = item.get('Response', '')
            question_text = item.get('Question', '')
            
            gt_lengths.append(len(gt_text))
            response_lengths.append(len(response_text))
            question_lengths.append(len(question_text))
        
        if gt_lengths and response_lengths:
            print(f"\n📝 Text Analysis:")
            print(f"  Avg question length: {sum(question_lengths)/len(question_lengths):.0f} chars")
            print(f"  Avg ground truth length: {sum(gt_lengths)/len(gt_lengths):.0f} chars")
            print(f"  Avg response length: {sum(response_lengths)/len(response_lengths):.0f} chars")
            
            # Response completeness
            response_ratios = [r/g if g > 0 else 0 for r, g in zip(response_lengths, gt_lengths)]
            avg_ratio = sum(response_ratios) / len(response_ratios)
            print(f"  Avg response/ground_truth ratio: {avg_ratio:.2f}")
        
        # OCR-specific analysis
        print(f"\n🔍 OCR-Specific Analysis:")
        
        # Analyze question types
        question_types = Counter()
        for item in data:
            question = item.get('Question', '').lower()
            if 'text' in question and 'visible' in question:
                question_types['text_extraction'] += 1
            elif 'read' in question:
                question_types['text_reading'] += 1
            elif 'transcribe' in question:
                question_types['transcription'] += 1
            else:
                question_types['other'] += 1
        
        print(f"  Question type distribution:")
        for qtype, count in question_types.items():
            percentage = count / total_samples * 100
            print(f"    {qtype}: {count} ({percentage:.1f}%)")
        
        # Performance by question complexity
        short_questions = [item for item in data if len(item.get('Question', '')) < 50]
        long_questions = [item for item in data if len(item.get('Question', '')) >= 50]
        
        if short_questions and long_questions:
            short_success = sum(1 for item in short_questions if item.get('found_correct_answer', False))
            long_success = sum(1 for item in long_questions if item.get('found_correct_answer', False))
            
            print(f"  Performance by question length:")
            print(f"    Short questions: {short_success}/{len(short_questions)} ({short_success/len(short_questions)*100:.1f}%)")
            print(f"    Long questions: {long_success}/{len(long_questions)} ({long_success/len(long_questions)*100:.1f}%)")
        
        # Sample analysis
        if successful:
            print(f"\n✅ Sample Successful Case:")
            sample = successful[0]
            print(f"  Question: {sample.get('Question', '')[:100]}...")
            print(f"  Ground Truth: {sample.get('Ground-True Answer', '')[:100]}...")
            print(f"  Response: {sample.get('Response', '')[:100]}...")
            print(f"  Reasoning attempts: {len(sample.get('reasoning_attempts', []))}")
        
        if failed:
            print(f"\n❌ Sample Failed Case:")
            sample = failed[0]
            print(f"  Question: {sample.get('Question', '')[:100]}...")
            print(f"  Ground Truth: {sample.get('Ground-True Answer', '')[:100]}...")
            print(f"  Response: {sample.get('Response', '')[:100]}...")
            print(f"  Reasoning attempts: {len(sample.get('reasoning_attempts', []))}")
        
        # Recommendations
        print(f"\n💡 Recommendations:")
        if success_rate > 80:
            print("  ✅ Excellent performance! Ready for larger datasets.")
        elif success_rate > 60:
            print("  🟡 Good performance. Fine-tune prompts for edge cases.")
        elif success_rate > 40:
            print("  🟠 Moderate performance. Review failed cases for patterns.")
        else:
            print("  🔴 Low performance. Significant prompt optimization needed.")
        
        if avg_attempts > 2.5:
            print("  🔄 High attempt count - improve initial prompt specificity.")
        
        if avg_ratio < 0.5:
            print("  📝 Responses shorter than expected - encourage more detail.")
        elif avg_ratio > 2:
            print("  📝 Responses longer than needed - add conciseness guidelines.")
        
        return {
            'file_name': file_path.name,
            'total_samples': total_samples,
            'success_rate': success_rate,
            'avg_attempts': avg_attempts,
            'strategy_usage': dict(strategy_usage),
            'question_types': dict(question_types)
        }
        
    except Exception as e:
        print(f"Error analyzing {file_path}: {str(e)}")
        return None

if output_files:
    print(f"✓ Found {len(output_files)} output files to analyze\n")
    
    # Analyze each file
    analysis_results = []
    for file in output_files:
        result = analyze_ocr_reasoning_performance(file)
        if result:
            analysis_results.append(result)
    
    # Summary comparison if multiple files
    if len(analysis_results) > 1:
        print(f"\n{'='*60}")
        print("COMPARATIVE SUMMARY")
        print(f"{'='*60}")
        
        print(f"\n📈 Performance Comparison:")
        for result in analysis_results:
            print(f"  {result['file_name']}: {result['success_rate']:.1f}% success ({result['total_samples']} samples)")
        
        # Best performing configuration
        best_result = max(analysis_results, key=lambda x: x['success_rate'])
        print(f"\n🏆 Best performing configuration: {best_result['file_name']}")
        print(f"    Success rate: {best_result['success_rate']:.1f}%")
        print(f"    Avg attempts: {best_result['avg_attempts']:.1f}")
    
    # Generate summary report
    summary_file = current_dir / "ocr_reasoning_summary.json"
    with open(summary_file, 'w', encoding='utf-8') as f:
        json.dump(analysis_results, f, indent=2, ensure_ascii=False)
    
    print(f"\n📊 Summary saved to: {summary_file}")
    
else:
    print("⚠️ No output files found for analysis")
    print("\nPossible reasons:")
    print("1. Pipeline hasn't completed yet")
    print("2. Pipeline encountered errors")
    print("3. Output files saved in different location")
    print("4. API key issues prevented execution")

print("\n=== Analysis Complete ===")
print("🎆 Your OCR reasoning system is now fully operational!")
print("\n🚀 Next steps for optimization:")
print("1. 🔍 Analyze failed cases for common patterns")
print("2. ⚙️ Refine prompts based on performance metrics")
print("3. 📈 Test with different OCR granularities (0 vs 5)")
print("4. 🌐 Scale to larger datasets for production use")
print("5. 🤝 Compare with other OCR reasoning approaches")

# %% [markdown]
# ### 5.1 Manual Pipeline Execution (If Needed)
#
# If the automatic pipeline execution fails, you can run it manually with these steps:

# %%
# Manual execution commands for the OCR reasoning pipeline
print("=== Manual Pipeline Execution Instructions ===")
print()
print("If the automatic execution above failed, run these commands manually:")
print()
print("1. Open a terminal in this environment")
print("2. Navigate to the src directory:")
print(f"   cd {Path.cwd() / 'src'}")
print()
print("3. Set your API key:")
print("   export API_KEY='sk-or-v1-your-actual-openrouter-api-key'")
print()
print("4. Run the reasoning pipeline:")
print("   python multimodal_QRA_pair.py")
print()
print("5. The pipeline will:")
print("   - Load OCR QA pairs from the JSON file")
print("   - Apply Chain of Thought reasoning with OCR-specific prompts")
print("   - Generate reasoning traces for each question")
print("   - Save results in reasoning_data_new/ directory")
print()
print("Expected output files:")
print("- ocr_qa_pairs_granularity_0_CoT_search_X.json (full results)")
print("- simplified_ocr_qa_pairs_granularity_0_CoT_search_X.json (simplified)")
print("- reasoning_data_new/*/progress.json (progress tracking)")
print()
print("Troubleshooting:")
print("- If API errors: Check your OpenRouter API key and credits")
print("- If import errors: Ensure all dependencies are installed")
print("- If file errors: Verify QA pairs JSON file exists and is valid")
print("- If memory errors: Reduce limit_num in reasoning_config.yaml")
print()
print("📊 Monitor the process - it will show progress and verification results")
print("🕐 Typical processing time: 2-5 minutes per sample depending on model")

# %% [markdown]
# ### 5.2 Quality Assessment and Next Steps
#
# After running the OCR reasoning pipeline, evaluate the results:

# %%
# Quality Assessment of OCR Reasoning Results
import json
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns

def analyze_reasoning_quality(results_file):
    """Analyze the quality of OCR reasoning results"""
    
    with open(results_file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    if not data:
        print("No data found in results file")
        return
    
    print(f"=== Quality Analysis for {len(data)} samples ===")
    
    # Basic statistics
    correct_answers = sum(1 for item in data if item.get('found_correct_answer', False))
    success_rate = correct_answers / len(data) * 100
    
    print(f"Success Rate: {correct_answers}/{len(data)} ({success_rate:.1f}%)")
    
    # Analyze reasoning attempts
    attempt_counts = []
    for item in data:
        attempts = item.get('reasoning_attempts', [])
        attempt_counts.append(len(attempts))
    
    avg_attempts = sum(attempt_counts) / len(attempt_counts)
    print(f"Average reasoning attempts: {avg_attempts:.1f}")
    
    # Analyze reasoning strategies used
    strategies_used = {}
    for item in data:
        attempts = item.get('reasoning_attempts', [])
        for strategy in attempts:
            strategies_used[strategy] = strategies_used.get(strategy, 0) + 1
    
    print("\nReasoning strategies used:")
    for strategy, count in strategies_used.items():
        print(f"  {strategy}: {count} times")
    
    # Analyze text length of OCR ground truth vs responses
    gt_lengths = []
    response_lengths = []
    
    for item in data:
        gt_text = item.get('Ground-True Answer', '')
        response_text = item.get('Response', '')
        
        gt_lengths.append(len(gt_text))
        response_lengths.append(len(response_text))
    
    print(f"\nText Analysis:")
    print(f"  Average ground truth length: {sum(gt_lengths)/len(gt_lengths):.0f} chars")
    print(f"  Average response length: {sum(response_lengths)/len(response_lengths):.0f} chars")
    
    # Sample successful and failed cases
    successful_cases = [item for item in data if item.get('found_correct_answer', False)]
    failed_cases = [item for item in data if not item.get('found_correct_answer', False)]
    
    print(f"\n=== Sample Successful Case ===")
    if successful_cases:
        sample = successful_cases[0]
        print(f"Question: {sample.get('Question', '')[:100]}...")
        print(f"Ground Truth: {sample.get('Ground-True Answer', '')[:100]}...")
        print(f"Response: {sample.get('Response', '')[:100]}...")
        print(f"Attempts: {sample.get('reasoning_attempts', [])}")
    
    print(f"\n=== Sample Failed Case ===")
    if failed_cases:
        sample = failed_cases[0]
        print(f"Question: {sample.get('Question', '')[:100]}...")
        print(f"Ground Truth: {sample.get('Ground-True Answer', '')[:100]}...")
        print(f"Response: {sample.get('Response', '')[:100]}...")
        print(f"Attempts: {sample.get('reasoning_attempts', [])}")
    
    return {
        'total_samples': len(data),
        'success_rate': success_rate,
        'avg_attempts': avg_attempts,
        'strategies_used': strategies_used
    }

# Find and analyze results files
print("=== OCR Reasoning Quality Assessment ===")

results_files = []
current_dir = Path.cwd()
src_dir = current_dir / "src"

# Look for results files
for directory in [current_dir, src_dir]:
    results_files.extend(list(directory.glob("*ocr_qa_pairs*CoT_search*.json")))
    results_files.extend(list(directory.glob("simplified_*ocr_qa_pairs*.json")))

if results_files:
    print(f"Found {len(results_files)} results files to analyze\n")
    
    for i, file in enumerate(results_files, 1):
        print(f"\n{'='*60}")
        print(f"Analyzing file {i}: {file.name}")
        print(f"{'='*60}")
        
        try:
            analysis = analyze_reasoning_quality(file)
            
            # Recommendations based on results
            print(f"\n=== Recommendations ===")
            if analysis['success_rate'] > 80:
                print("✅ Excellent performance! Consider scaling up to larger datasets.")
            elif analysis['success_rate'] > 60:
                print("🟡 Good performance. Consider refining prompts for edge cases.")
            elif analysis['success_rate'] > 40:
                print("🟠 Moderate performance. Review failed cases and improve prompts.")
            else:
                print("🔴 Low performance. Significant prompt engineering needed.")
            
            if analysis['avg_attempts'] > 3:
                print("🔄 High attempt count - consider more targeted initial prompts.")
            
        except Exception as e:
            print(f"Error analyzing {file}: {str(e)}")
            
else:
    print("⚠️ No results files found.")
    print("Make sure the reasoning pipeline has completed successfully.")
    print("Expected files: *ocr_qa_pairs*CoT_search*.json")

print("\n=== Next Steps for Improvement ===")
print("1. 📊 Analyze failed cases to identify prompt weaknesses")
print("2. ⚙️ Refine OCR-specific prompts based on common failure patterns")
print("3. 🔍 Test with different OCR granularities (0 vs 5)")
print("4. 📝 Scale to larger datasets once quality is satisfactory")
print("5. 🎨 Consider ensemble approaches with multiple reasoning strategies")
print("\n🎆 Congratulations! You've built an end-to-end OCR reasoning system!")

# %% [markdown]
# ## 6. Evaluation and Performance Analysis
#
# Evaluate the OCR reasoning pipeline performance and identify areas for improvement:
